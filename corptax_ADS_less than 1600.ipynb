# %%
import pandas as pd
import numpy as np
from scalecast.Forecaster import Forecaster
from scalecast.auxmodels import auto_arima
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(14,7)})

# %%
df = pd.read_csv('Corptax_all.csv')
df[['Date Closed','Date Created']] = df[['Date Closed','Date Created']].apply(pd.to_datetime, errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190892 entries, 0 to 190891
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         190892 non-null  int64
#  1   index              190892 non-null  int64
#  2   Case Number        190892 non-null  int64
#  3   Subject            190891 non-null  object
#  4   Date Created       190892 non-null  datetime64[ns]
#  5   Date Closed        190772 non-null  datetime64[ns]
#  6   Origin             190892 non-null  object
#  7   Priority           190892 non-null  object
#  8   Team               190890 non-null  object
#  9   Case Type          187269 non-null  object
#  10  SLA                190843 non-null  object
#  11  Problem Statement  187361 non-null  object
#  12  Product            190765 non-null  object
#  13  Product Area       190672 non-null  object
#  14  Product Category   47725 non-null   object
#  15  Product Type       5179 non-null    object
#  16  Jurisdiction       123161 non-null  object
#  17  Resolution         187773 non-null  object
#  18  KB #               52300 non-null   object
#  19  KB Title           50237 non-null   object
# dtypes: datetime64[ns](2), int64(3), object(15)
# memory usage: 29.1+ MB

# %%
fill_dt = pd.Timestamp.now().normalize()
df['Date Closed'] = df['Date Closed'].fillna(fill_dt)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# index                     0
# Case Number               0
# Subject                   1
# Date Created              0
# Date Closed               0
# Origin                    0
# Priority                  0
# Team                      2
# Case Type              3623
# SLA                      49
# Problem Statement      3531
# Product                 127
# Product Area            220
# Product Category     143167
# Product Type         185713
# Jurisdiction          67731
# Resolution             3119
# KB #                 138592
# KB Title             140655
# dtype: int64

# %%
df = df.dropna(axis=0, subset=['Product', 'Product Area'])

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# index                     0
# Case Number               0
# Subject                   1
# Date Created              0
# Date Closed               0
# Origin                    0
# Priority                  0
# Team                      2
# Case Type              3610
# SLA                      47
# Problem Statement      3522
# Product                   0
# Product Area              0
# Product Category     142947
# Product Type         185493
# Jurisdiction          67618
# Resolution             3109
# KB #                 138420
# KB Title             140483
# dtype: int64

# %%
df['Year']= df['Date Created'].dt.year
df['Month']= df['Date Created'].dt.month
df['Week']= df['Date Created'].dt.isocalendar().week
df['week_num'] = df['Week'] + (df['Year'] - df['Year'].min())*52

# %%
df['Date'] = df['Date Created'].dt.date 
drop_columns = ['Date Closed','Date Created','Unnamed: 0',]
df.drop(drop_columns, axis=1, inplace=True)
df.head()
# Out:
#    index  Case Number                                            Subject  \
# 0      0       204977                                   Efile Acceptance
# 1      1       204979  Oregon STAT help: Previous Case 203787 Client ...
# 2      2       204980             Data map incorrectly pulling in values
# 3      3       204981  The New Corptax Connect Website is not properl...
# 4      4       204986     LD400 is not reflecting a temporary adjustment
#
#    Origin Priority             Team          Case Type       SLA  \
# 0     Web   Medium  Tax Preparation              Efile  Platinum
# 1     Web     High  Tax Preparation  Question / How To    Silver
# 2     Web   Medium  Tax Preparation  Question / How To    Silver
# 3     Web     High  Tax Preparation    Problem / Error    Silver
# 4  E-mail   Medium  Tax Preparation    Problem / Error  Platinum
#
#                                    Problem Statement                Product  \
# 0  We transmitted a Michigan return still have no...             Compliance
# 1  Oregon STAT help: Previous Case 203787 Client ...              Provision
# 2  Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 3  Searches can't be performed on the new system....               Websites
# 4     LD400 is not reflecting a temporary adjustment             Compliance
#
#    ... Product Type Jurisdiction                           Resolution  \
# 0  ...          NaN        US.MI                     Answer exists KB
# 1  ...          NaN        US.OR  Customer no longer needs assistance
# 2  ...          NaN           US                     Answer exists KB
# 3  ...          NaN          NaN                     Answer exists KB
# 4  ...          NaN           US                     Answer exists KB
#
#               KB #                                           KB Title  Year  \
# 0  041324813494120         How to understand the Transmission Monitor  2017
# 1              NaN                                                NaN  2017
# 2  041414821333274  Corptax® Office - How to place an IF formula i...  2017
# 3  161216104028927  Connections Error - Uh Oh  something went wron...  2017
# 4  041622907012748  Adjustments do not flow to LD400 workpaper and...  2017
#
#   Month  Week  week_num        Date
# 0     1     1         1  2017-01-02
# 1     1     1         1  2017-01-02
# 2     1     1         1  2017-01-02
# 3     1     1         1  2017-01-02
# 4     1     1         1  2017-01-03
#
# [5 rows x 22 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

# %%
df.rename(columns={'Case Number':'Case_Number', 'Product Area': 'Product_Area'}, inplace=True)

# %%
df['PPA'] = df['Product'] + " : " + df['Product_Area']
df.head()
# Out:
#    index  Case_Number                                            Subject  \
# 0      0       204977                                   Efile Acceptance
# 1      1       204979  Oregon STAT help: Previous Case 203787 Client ...
# 2      2       204980             Data map incorrectly pulling in values
# 3      3       204981  The New Corptax Connect Website is not properl...
# 4      4       204986     LD400 is not reflecting a temporary adjustment
#
#    Origin Priority             Team          Case Type       SLA  \
# 0     Web   Medium  Tax Preparation              Efile  Platinum
# 1     Web     High  Tax Preparation  Question / How To    Silver
# 2     Web   Medium  Tax Preparation  Question / How To    Silver
# 3     Web     High  Tax Preparation    Problem / Error    Silver
# 4  E-mail   Medium  Tax Preparation    Problem / Error  Platinum
#
#                                    Problem Statement                Product  \
# 0  We transmitted a Michigan return still have no...             Compliance
# 1  Oregon STAT help: Previous Case 203787 Client ...              Provision
# 2  Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 3  Searches can't be performed on the new system....               Websites
# 4     LD400 is not reflecting a temporary adjustment             Compliance
#
#    ... Jurisdiction                           Resolution             KB #  \
# 0  ...        US.MI                     Answer exists KB  041324813494120
# 1  ...        US.OR  Customer no longer needs assistance              NaN
# 2  ...           US                     Answer exists KB  041414821333274
# 3  ...          NaN                     Answer exists KB  161216104028927
# 4  ...           US                     Answer exists KB  041622907012748
#
#                                             KB Title  Year Month Week  \
# 0         How to understand the Transmission Monitor  2017     1    1
# 1                                                NaN  2017     1    1
# 2  Corptax® Office - How to place an IF formula i...  2017     1    1
# 3  Connections Error - Uh Oh  something went wron...  2017     1    1
# 4  Adjustments do not flow to LD400 workpaper and...  2017     1    1
#
#    week_num       Date                                                PPA
# 0         1 2017-01-02                     Compliance : Returns / Reports
# 1         1 2017-01-02                                  Provision : State
# 2         1 2017-01-02            Office - Excel Add-In : Import / Export
# 3         1 2017-01-02  Websites : Connections (https://connect.corpta...
# 4         1 2017-01-03                     Compliance : Returns / Reports
#
# [5 rows x 23 columns]

# %%
df.PPA.nunique()
# Out:
# 113

# %%
filter = ['Compliance', 'International (US)','Office - Excel Add-In','Provision','Partnership / S Corp / Pass-Through']
df1 =  df[df['Product'].isin(filter)]
df1.head()
# Out:
#    index  Case_Number                                            Subject  \
# 0      0       204977                                   Efile Acceptance
# 1      1       204979  Oregon STAT help: Previous Case 203787 Client ...
# 2      2       204980             Data map incorrectly pulling in values
# 4      4       204986     LD400 is not reflecting a temporary adjustment
# 6      6       204992                           Form 2220 Line 19 dates.
#
#    Origin Priority             Team          Case Type       SLA  \
# 0     Web   Medium  Tax Preparation              Efile  Platinum
# 1     Web     High  Tax Preparation  Question / How To    Silver
# 2     Web   Medium  Tax Preparation  Question / How To    Silver
# 4  E-mail   Medium  Tax Preparation    Problem / Error  Platinum
# 6     Web   Medium  Tax Preparation    Problem / Error  Platinum
#
#                                    Problem Statement                Product  \
# 0  We transmitted a Michigan return still have no...             Compliance
# 1  Oregon STAT help: Previous Case 203787 Client ...              Provision
# 2  Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 4     LD400 is not reflecting a temporary adjustment             Compliance
# 6  Form 2220 Line 19 dates are repeating. This is...             Compliance
#
#    ... Jurisdiction                           Resolution             KB #  \
# 0  ...        US.MI                     Answer exists KB  041324813494120
# 1  ...        US.OR  Customer no longer needs assistance              NaN
# 2  ...           US                     Answer exists KB  041414821333274
# 4  ...           US                     Answer exists KB  041622907012748
# 6  ...           US                     Answer exists KB  041335414275440
#
#                                             KB Title  Year Month Week  \
# 0         How to understand the Transmission Monitor  2017     1    1
# 1                                                NaN  2017     1    1
# 2  Corptax® Office - How to place an IF formula i...  2017     1    1
# 4  Adjustments do not flow to LD400 workpaper and...  2017     1    1
# 6  IRS e-Services and Business MeF Maintenance in...  2017     1    1
#
#    week_num       Date                                      PPA
# 0         1 2017-01-02           Compliance : Returns / Reports
# 1         1 2017-01-02                        Provision : State
# 2         1 2017-01-02  Office - Excel Add-In : Import / Export
# 4         1 2017-01-03           Compliance : Returns / Reports
# 6         1 2017-01-03                     Compliance : Amounts
#
# [5 rows x 23 columns]

# %%
all_val = df1.PPA.value_counts()
all_val
# Out:
# Compliance : Returns / Reports                             77888
# International (US) : Returns / Reports                     14589
# Compliance : Amounts                                        8515
# Compliance : Install / Rollover                             7121
# Compliance : Configuration / Setup                          5964
# Partnership / S Corp / Pass-Through : Returns / Reports     5927
# International (US) : Foreign Processing                     5461
# Provision : Federal                                         4489
# Compliance : Import / Export                                3299
# Compliance : Environment Maintenance                        3187
# International (US) : Tax Cuts and Jobs Act                  3089
# International (US) : Calculation / Posting                  3041
# Provision : Configuration / Setup                           2787
# Provision : State                                           1901
# International (US) : Configuration / Setup                  1673
# Compliance : BEPS CbC                                       1344
# Office - Excel Add-In : Import / Export                     1327
# Partnership / S Corp / Pass-Through : K1 Data               1294
# Compliance : Printing                                       1281
# Compliance : Backup / Restore                                925
# Office - Excel Add-In : Functions                            890
# International (US) : Domestic Processing                     724
# Office - Excel Add-In : Excel Templates                      706
# Partnership / S Corp / Pass-Through : Allocate               700
# Office - Excel Add-In : Data Connections                     656
# Partnership / S Corp / Pass-Through : Amounts                511
# Compliance : Tax Cuts and Jobs Act                           453
# Provision : Import / Export                                  420
# Compliance : System Requirements                             383
# Partnership / S Corp / Pass-Through : Setup                  367
# Compliance : Entity Obligations                              322
# International (US) : Import                                  297
# Partnership / S Corp / Pass-Through : K2/K3                  285
# Compliance : Trainer on Call                                 233
# Office - Excel Add-In : Data Profile                         210
# Provision : Tax Contingency (FIN48)                          156
# Partnership / S Corp / Pass-Through : Import / Export        110
# Provision : Login                                            101
# Compliance : Login                                           100
# Provision : Install                                           93
# International (US) : Trainer on Call                          50
# Provision : Trainer on Call                                   30
# Compliance : Security Assessment                              24
# Office - Excel Add-In : Trainer on Call                       24
# International (US) : Install                                  23
# Partnership / S Corp / Pass-Through : Install                 18
# International (US) : Login                                    17
# Office - Excel Add-In : Install                               16
# Partnership / S Corp / Pass-Through : Login                   10
# Partnership / S Corp / Pass-Through : Trainer on Call          9
# Office - Excel Add-In : Login                                  4
# Compliance : Global Minimum Tax (GMT)                          2
# Provision : Security Assessment                                2
# Partnership / S Corp / Pass-Through : Federal                  1
# Name: PPA, dtype: int64

# %%
filter2 = list(df1.PPA.value_counts()[df1.PPA.value_counts() < 1600].index)
len(filter2)
# Out:
# 39

# %%
filter2
# Out:
# ['Compliance : BEPS CbC',
#  'Office - Excel Add-In : Import / Export',
#  'Partnership / S Corp / Pass-Through : K1 Data',
#  'Compliance : Printing',
#  'Compliance : Backup / Restore',
#  'Office - Excel Add-In : Functions',
#  'International (US) : Domestic Processing',
#  'Office - Excel Add-In : Excel Templates',
#  'Partnership / S Corp / Pass-Through : Allocate',
#  'Office - Excel Add-In : Data Connections',
#  'Partnership / S Corp / Pass-Through : Amounts',
#  'Compliance : Tax Cuts and Jobs Act',
#  'Provision : Import / Export',
#  'Compliance : System Requirements',
#  'Partnership / S Corp / Pass-Through : Setup',
#  'Compliance : Entity Obligations',
#  'International (US) : Import',
#  'Partnership / S Corp / Pass-Through : K2/K3',
#  'Compliance : Trainer on Call',
#  'Office - Excel Add-In : Data Profile',
#  'Provision : Tax Contingency (FIN48)',
#  'Partnership / S Corp / Pass-Through : Import / Export',
#  'Provision : Login',
#  'Compliance : Login',
#  'Provision : Install',
#  'International (US) : Trainer on Call',
#  'Provision : Trainer on Call',
#  'Compliance : Security Assessment',
#  'Office - Excel Add-In : Trainer on Call',
#  'International (US) : Install',
#  'Partnership / S Corp / Pass-Through : Install',
#  'International (US) : Login',
#  'Office - Excel Add-In : Install',
#  'Partnership / S Corp / Pass-Through : Login',
#  'Partnership / S Corp / Pass-Through : Trainer on Call',
#  'Office - Excel Add-In : Login',
#  'Compliance : Global Minimum Tax (GMT)',
#  'Provision : Security Assessment',
#  'Partnership / S Corp / Pass-Through : Federal']

# %%
df2 =  df[df['PPA'].isin(filter2)]
df2.head()
# Out:
#      index  Case_Number                                            Subject  \
# 2        2       204980             Data map incorrectly pulling in values
# 35      35       205047                      OECD BEPS CbC Dividend Income
# 55      55       205101  Cannot print the first two pages of the IN Par...
# 58      58       205111                                     Corptax OFFICE
# 107    107       205227                Corptax Office Sample Template 4797
#
#      Origin Priority             Team          Case Type     SLA  \
# 2       Web   Medium  Tax Preparation  Question / How To  Silver
# 35      Web   Medium  Tax Preparation  Question / How To  Silver
# 55      Web   Medium  Tax Preparation    Problem / Error  Silver
# 58      Web     High  Tax Preparation  Question / How To  Silver
# 107  E-mail   Medium  Tax Preparation  Question / How To  Silver
#
#                                      Problem Statement                Product  \
# 2    Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 35   OECD guidelines and IRS regs indicate that div...             Compliance
# 55   Cannot print the first two pages of the IN Par...             Compliance
# 58   Have question on the need to license Corptax O...  Office - Excel Add-In
# 107  Corptax Office: Is there a sample template ava...  Office - Excel Add-In
#
#      ... Jurisdiction                                         Resolution  \
# 2    ...           US                                   Answer exists KB
# 35   ...          NaN                                   Create/Update KB
# 55   ...        US.IN  Provide solution - no KB required (e.g. client...
# 58   ...          NaN  Provide solution - no KB required (e.g. client...
# 107  ...          NaN                                   Answer exists KB
#
#                 KB #                                           KB Title  Year  \
# 2    041414821333274  Corptax® Office - How to place an IF formula i...  2017
# 35               NaN                                                NaN  2017
# 55               NaN                                                NaN  2017
# 58               NaN                                                NaN  2017
# 107  041320517154121  Corptax® Office - Sample Templates (Best Pract...  2017
#
#     Month Week  week_num       Date                                      PPA
# 2       1    1         1 2017-01-02  Office - Excel Add-In : Import / Export
# 35      1    1         1 2017-01-03                    Compliance : BEPS CbC
# 55      1    1         1 2017-01-03                    Compliance : Printing
# 58      1    1         1 2017-01-03        Office - Excel Add-In : Functions
# 107     1    1         1 2017-01-04  Office - Excel Add-In : Import / Export
#
# [5 rows x 23 columns]

# %%
monthly_corr.Monthly_value = abs(monthly_corr.Monthly_value)

# %%
sorted_corr = monthly_corr.sort_values(by = "Monthly_value", ascending=False)
sorted_corr
# Out:
#                                             PPA1  \
# 0                           Compliance : Amounts
# 825                 Compliance : Trainer on Call
# 1430    Office - Excel Add-In : Data Connections
# 1375        International (US) : Trainer on Call
# 1320  International (US) : Tax Cuts and Jobs Act
# ...                                          ...
# 2540                 Provision : Import / Export
# 769           Compliance : Tax Cuts and Jobs Act
# 716             Compliance : System Requirements
# 1074     International (US) : Foreign Processing
# 2611                         Provision : Install
#
#                                             PPA2  Monthly_value
# 0                           Compliance : Amounts       1.000000
# 825                 Compliance : Trainer on Call       1.000000
# 1430    Office - Excel Add-In : Data Connections       1.000000
# 1375        International (US) : Trainer on Call       1.000000
# 1320  International (US) : Tax Cuts and Jobs Act       1.000000
# ...                                          ...            ...
# 2540               Compliance : Backup / Restore       0.000623
# 769             Compliance : System Requirements       0.000316
# 716           Compliance : Tax Cuts and Jobs Act       0.000316
# 1074                         Provision : Install       0.000055
# 2611     International (US) : Foreign Processing       0.000055
#
# [2916 rows x 3 columns]

# %%
filter2
# Out:
# ['Compliance : BEPS CbC',
#  'Office - Excel Add-In : Import / Export',
#  'Partnership / S Corp / Pass-Through : K1 Data',
#  'Compliance : Printing',
#  'Compliance : Backup / Restore',
#  'Office - Excel Add-In : Functions',
#  'International (US) : Domestic Processing',
#  'Office - Excel Add-In : Excel Templates',
#  'Partnership / S Corp / Pass-Through : Allocate',
#  'Office - Excel Add-In : Data Connections',
#  'Partnership / S Corp / Pass-Through : Amounts',
#  'Compliance : Tax Cuts and Jobs Act',
#  'Provision : Import / Export',
#  'Compliance : System Requirements',
#  'Partnership / S Corp / Pass-Through : Setup',
#  'Compliance : Entity Obligations',
#  'International (US) : Import',
#  'Partnership / S Corp / Pass-Through : K2/K3',
#  'Compliance : Trainer on Call',
#  'Office - Excel Add-In : Data Profile',
#  'Provision : Tax Contingency (FIN48)',
#  'Partnership / S Corp / Pass-Through : Import / Export',
#  'Provision : Login',
#  'Compliance : Login',
#  'Provision : Install',
#  'International (US) : Trainer on Call',
#  'Provision : Trainer on Call',
#  'Compliance : Security Assessment',
#  'Office - Excel Add-In : Trainer on Call',
#  'International (US) : Install',
#  'Partnership / S Corp / Pass-Through : Install',
#  'International (US) : Login',
#  'Office - Excel Add-In : Install',
#  'Partnership / S Corp / Pass-Through : Login',
#  'Partnership / S Corp / Pass-Through : Trainer on Call',
#  'Office - Excel Add-In : Login',
#  'Compliance : Global Minimum Tax (GMT)',
#  'Provision : Security Assessment',
#  'Partnership / S Corp / Pass-Through : Federal']

# %% [markdown]
# # for Compliance

# %%
[k for k in filter2 if 'Compliance' in k]
# Out:
# ['Compliance : BEPS CbC',
#  'Compliance : Printing',
#  'Compliance : Backup / Restore',
#  'Compliance : Tax Cuts and Jobs Act',
#  'Compliance : System Requirements',
#  'Compliance : Entity Obligations',
#  'Compliance : Trainer on Call',
#  'Compliance : Login',
#  'Compliance : Security Assessment',
#  'Compliance : Global Minimum Tax (GMT)']

# %%
# if (sorted_corr[sorted_corr['PPA1'].isin([i])][1:3]["Monthly_value"].values > 0.4):

# %%
for i in [k for k in filter2 if 'Compliance' in k]:
    if sorted_corr[sorted_corr['PPA1'].isin([i])][1:3]["Monthly_value"].values[0] > 0.7:
        print(i)
        print(sorted_corr[sorted_corr['PPA1'].isin([i])][1:3]["PPA2"].values)
        print(sorted_corr[sorted_corr['PPA1'].isin([i])][1:3]["Monthly_value"].values)
        print("============================")
# Out:
# Compliance : BEPS CbC
# ['International (US) : Domestic Processing' 'Compliance : Amounts']
# [0.72816268 0.56865158]
# ============================
# Compliance : Tax Cuts and Jobs Act
# ['International (US) : Tax Cuts and Jobs Act'
#  'Compliance : Trainer on Call']
# [0.79567905 0.61304201]
# ============================
# Compliance : Trainer on Call
# ['Compliance : Returns / Reports' 'Compliance : Tax Cuts and Jobs Act']
# [0.73688284 0.61304201]
# ============================
# Compliance : Login
# ['Office - Excel Add-In : Login' 'Office - Excel Add-In : Install']
# [1. 1.]
# ============================
# Compliance : Security Assessment
# ['Compliance : Global Minimum Tax (GMT)' 'Provision : Security Assessment']
# [0.92493186 0.75557484]
# ============================
# Compliance : Global Minimum Tax (GMT)
# ['Compliance : Security Assessment' 'Compliance : Login']
# [0.92493186 0.70181003]
# ============================

# %% [markdown]
# ### Compliance : Global Minimum Tax (GMT) || Compliance : Security Assessment (0.9249)

# %%
df[(df.a != -1) & (df.b != -1)]

# %%
temp = df[(df['Product'].isin(["Compliance"])) | (df['PPA'].isin(["Compliance : Security Assessment"]))]
len(temp)
# Out:
# 111041

# %%
temp = temp[temp['PPA'].isin(["Compliance : Security Assessment"])]
len(temp)
# Out:
# 24

# %%
# temp_fill = ["Compliance : Global Minimum Tax (GMT)","Compliance : Security Assessment"] #very less
# temp_fill = ['Compliance : Global Minimum Tax (GMT)','Provision : Security Assessment'] #very less
# temp_fill = ['International (US) : Domestic Processing','Compliance : Amounts'] not eligible 
#temp_fill = ['Compliance : Global Minimum Tax (GMT)','Compliance : Security Assessment']
temp_fill = ['Compliance : Amounts','Compliance : Returns / Reports']
temp_fill = ['Compliance : Global Minimum Tax (GMT)','Compliance : Login']
temp_fill = ['Compliance : Returns / Reports','Compliance : Trainer on Call']
temp_fill = ['Compliance : Global Minimum Tax (GMT)','Compliance : Login']
temp_fill = ['Compliance : Tax Cuts and Jobs Act','Compliance : Trainer on Call']
temp_fill = ['International (US) : Calculation / Posting','International (US) : Returns / Reports']
temp_fill = ['International (US) : Foreign Processing','International (US) : Returns / Reports']
temp_fill = ['International (US) : Calculation / Posting','International (US) : Foreign Processing']
temp_fill = ["International (US) : Calculation / Posting",'International (US) : Trainer on Call']
temp_fill = ["Office - Excel Add-In : Data Profile","Office - Excel Add-In : Import / Export"]
temp_fill = ["Partnership / S Corp / Pass-Through : K1 Data","Partnership / S Corp / Pass-Through : Returns / Reports"]
for i in temp_fill:
    print(all_val[i])
# Out:
# 1294
# 5927

# %%
temp_df =  df[df['PPA'].isin(temp_fill)]
temp_df.PPA.value_counts().sum()
# Out:
# 7221

# %%
# temp = df1[df1.PPA == "Compliance : Tax Cuts and Jobs Act"][["Case_Number","Date"]]
# newdf = pd.DataFrame(temp.groupby([temp["Date"].dt.date]).count()["Case_Number"])
# newdf = newdf.reset_index()
# newdf.index = newdf.Date
# newdf['Date'] = pd.to_datetime(newdf['Date'], errors='coerce')
# newdf = newdf.asfreq('D')
# newdf = newdf.groupby(pd.Grouper(freq="M")).sum()
# len(newdf)

# %%
temp_df =  df[df['PPA'].isin(temp_fill)]
temp = temp_df
newdf = pd.DataFrame(temp.groupby([temp["Date"].dt.date]).count()["Case_Number"])
newdf = newdf.reset_index()
newdf.index = newdf.Date
newdf['Date'] = pd.to_datetime(newdf['Date'], errors='coerce')
newdf = newdf.asfreq('D')
newdf = newdf.groupby(pd.Grouper(freq="M")).sum()
len(newdf)
# Out:
# 68

# %%
newdf.sum()
# Out:
# Case_Number    26.0
# dtype: float64

# %%
print("length of dataframe : ",newdf.shape[0])
f = Forecaster(y=newdf['Case_Number'],current_dates=newdf.index)
f.generate_future_dates(12)
f.set_test_length(.2)
critical_pval = 0.05
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print('the series is {}'.format('stationary' if pval < critical_pval else 'not stationary'))
print("Lets Make Data Stationary First")
f.set_estimator('mlr')
f.add_ar_terms(12) 
f.add_seasonal_regressors('quarter',dummy=True) # 2.
f.add_time_trend() # 2.
f.diff()
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print('Now, This series is {}'.format('stationary' if pval < critical_pval else 'not stationary'))
f.manual_forecast()
results = f.export(to_excel=True,
           excel_name='mlr.xlsx')
print(results["model_summaries"]["InSampleRMSE"][0],2)
print(round(results["model_summaries"]["TestSetRMSE"][0],2))
# Out:
# length of dataframe :  68
# the series is not stationary
# Lets Make Data Stationary First
# Now, This series is stationary
# 295.7643107308625 2
# 259.16

# %%
# res = {}
# filter_list = list(df1.PPA.value_counts()[df1.PPA.value_counts() > 1600].index)
# filter_list = temp_fill
temp_df =  df[df['PPA'].isin(temp_fill)]
train_rmse = []
test_rmse = []
months = []
    
#grouping by month
temp = temp_df
newdf = pd.DataFrame(temp.groupby([temp["Date"].dt.date]).count()["Case_Number"])
newdf = newdf.reset_index()
newdf.index = newdf.Date
newdf['Date'] = pd.to_datetime(newdf['Date'], errors='coerce')
newdf = newdf.asfreq('D')
newdf = newdf.groupby(pd.Grouper(freq="M")).sum()

print("length of dataframe : ",newdf.shape[0])
f = Forecaster(y=newdf['Case_Number'],current_dates=newdf.index)
f.generate_future_dates(12)
f.set_test_length(.2)
critical_pval = 0.05
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print('the series is {}'.format('stationary' if pval < critical_pval else 'not stationary'))
    if pval < critical_pval:
        auto_arima(
            f,
            start_P=1,
            start_q=1,
            max_p=10,
            max_q=10,
            m=12,
            seasonal=True,
            max_P=10, 
            max_D=10,
            max_Q=10,
            max_d=10,
            trace=True,
            error_action='ignore',
            suppress_warnings=True,
            stepwise=True,
            information_criterion="aic",
            alpha=0.05,
            scoring='mse',
            call_me='auto_arima',)
        f.plot_test_set(ci=False,models='auto_arima')
        plt.title('ARIMA Test-Set Performance',size=14)
        plt.show()
        results = f.export(to_excel=True,excel_name='mlr.xlsx')
        train_rmse.append(round(results["model_summaries"]["InSampleRMSE"][0],2))
        test_rmse.append(round(results["model_summaries"]["TestSetRMSE"][0],2))
        
        for j in range(0,4):
            months.append(round(results["lvl_fcsts"].iloc[j]["auto_arima"]))
        model = "arima-S"
        res[i] = [model, train_rmse[0], test_rmse[0], newdf.min()[0], newdf.max()[0], newdf.mean()[0], newdf.std()[0],months[0],months[1],months[2],months[3]]

    else:
        print("Lets Make Data Stationary First")
        f.set_estimator('mlr')
        f.add_ar_terms(12) 
        f.add_seasonal_regressors('quarter',dummy=True) # 2.
        f.add_time_trend() # 2.
        f.diff()
        stat, pval, _, _, _, _ = f.adf_test(full_res=True)
        print('Now, This series is {}'.format('stationary' if pval < critical_pval else 'not stationary'))
        f.manual_forecast()
        results = f.export(to_excel=True,
                   excel_name='mlr.xlsx')
        train_rmse.append(round(results["model_summaries"]["InSampleRMSE"][0],2))
        test_rmse.append(round(results["model_summaries"]["TestSetRMSE"][0],2))
        
        for j in range(0,4):
            months.append(round(results["lvl_fcsts"].iloc[j]["mlr"]))
            
        model = "mlr-NS"
        res[i] = [model, train_rmse[0], test_rmse[0], newdf.min()[0], newdf.max()[0], newdf.mean()[0], newdf.std()[0],months[0],months[1],months[2],months[3]]
    print("============================END=================================")
# Out:
# Compliance : Returns / Reports
# length of dataframe :  68
# the series is not stationary
# Lets Make Data Stationary First
# Now, This series is stationary
# ============================END=================================
# Compliance : Tax Cuts and Jobs Act
# length of dataframe :  54
# the series is not stationary
# Lets Make Data Stationary First
# Now, This series is stationary
# ============================END=================================

# %%
ind = ["model","train_rmse","test_rmse","min", "max", "mean", "std", "sept", "oct", "nov", "dec"]
res_df = pd.DataFrame(res)
res_df.index = ind
round(res_df,2).T
# Out:
#                                                            model train_rmse  \
# Compliance : Returns / Reports                            mlr-NS     293.46
# International (US) : Returns / Reports                    mlr-NS      56.09
# Compliance : Amounts                                      mlr-NS      20.93
# Compliance : Install / Rollover                           mlr-NS      28.99
# Compliance : Configuration / Setup                        mlr-NS      13.82
# Partnership / S Corp / Pass-Through : Returns / Reports   mlr-NS      24.78
# International (US) : Foreign Processing                  arima-S      32.71
# Provision : Federal                                       mlr-NS      13.98
# Compliance : Import / Export                              mlr-NS        9.0
# Compliance : Environment Maintenance                     arima-S      47.74
# International (US) : Tax Cuts and Jobs Act                mlr-NS      12.39
# International (US) : Calculation / Posting               arima-S      21.69
# Provision : Configuration / Setup                        arima-S      11.99
# Provision : State                                         mlr-NS       6.95
# International (US) : Configuration / Setup               arima-S       8.14
#
#                                                         test_rmse    min  \
# Compliance : Returns / Reports                             254.61  456.0
# International (US) : Returns / Reports                      69.47   44.0
# Compliance : Amounts                                         28.7   33.0
# Compliance : Install / Rollover                             54.25   30.0
# Compliance : Configuration / Setup                          10.73   42.0
# Partnership / S Corp / Pass-Through : Returns / Reports     33.62    6.0
# International (US) : Foreign Processing                     32.03   19.0
# Provision : Federal                                         12.44   24.0
# Compliance : Import / Export                                10.06   11.0
# Compliance : Environment Maintenance                        24.59   14.0
# International (US) : Tax Cuts and Jobs Act                  13.23    0.0
# International (US) : Calculation / Posting                  12.03    7.0
# Provision : Configuration / Setup                            9.78   18.0
# Provision : State                                           10.28    5.0
# International (US) : Configuration / Setup                  10.48    7.0
#
#                                                             max         mean  \
# Compliance : Returns / Reports                           4449.0  1145.411765
# International (US) : Returns / Reports                    684.0   214.544118
# Compliance : Amounts                                      352.0   125.220588
# Compliance : Install / Rollover                           280.0   104.720588
# Compliance : Configuration / Setup                        164.0    87.705882
# Partnership / S Corp / Pass-Through : Returns / Reports   271.0    87.161765
# International (US) : Foreign Processing                   220.0    80.308824
# Provision : Federal                                       247.0    66.014706
# Compliance : Import / Export                              110.0    48.514706
# Compliance : Environment Maintenance                      393.0    46.867647
# International (US) : Tax Cuts and Jobs Act                334.0    57.203704
# International (US) : Calculation / Posting                166.0    44.720588
# Provision : Configuration / Setup                         100.0    40.985294
# Provision : State                                          79.0    27.955882
# International (US) : Configuration / Setup                 52.0    24.602941
#
#                                                                 std  sept  \
# Compliance : Returns / Reports                           799.908021  1496
# International (US) : Returns / Reports                   149.335387   489
# Compliance : Amounts                                      76.434704   208
# Compliance : Install / Rollover                           67.240012    78
# Compliance : Configuration / Setup                        26.948851    74
# Partnership / S Corp / Pass-Through : Returns / Reports   64.723663   215
# International (US) : Foreign Processing                   44.954789    97
# Provision : Federal                                       36.106597    51
# Compliance : Import / Export                              22.153126    32
# Compliance : Environment Maintenance                      50.457875    38
# International (US) : Tax Cuts and Jobs Act                72.929374    18
# International (US) : Calculation / Posting                31.394859    78
# Provision : Configuration / Setup                          16.28798    32
# Provision : State                                         15.411213    30
# International (US) : Configuration / Setup                 10.16159    27
#
#                                                           oct   nov  dec
# Compliance : Returns / Reports                           2107  1006  368
# International (US) : Returns / Reports                    241    99   68
# Compliance : Amounts                                      234   134   61
# Compliance : Install / Rollover                            75    42   37
# Compliance : Configuration / Setup                         44    30   17
# Partnership / S Corp / Pass-Through : Returns / Reports    40    31   13
# International (US) : Foreign Processing                    67    61   53
# Provision : Federal                                        50    44   37
# Compliance : Import / Export                                9     7    3
# Compliance : Environment Maintenance                       36    33   41
# International (US) : Tax Cuts and Jobs Act                 18    16   11
# International (US) : Calculation / Posting                 37    21   21
# Provision : Configuration / Setup                          31    30   32
# Provision : State                                          33    27   52
# International (US) : Configuration / Setup                 20    14   20

# %%
res_df
# Out:
#            Compliance : Returns / Reports  \
# model                                 mlr
# train_rmse                         293.46
# test_rmse                          254.61
# min                                 456.0
# max                                4449.0
# mean                          1145.411765
# std                            799.908021
# sept                                 1496
# oct                                  2107
# nov                                  1006
# dec                                   368
#
#            International (US) : Returns / Reports Compliance : Amounts  \
# model                                         mlr                  mlr
# train_rmse                                  56.09                20.93
# test_rmse                                   69.47                 28.7
# min                                          44.0                 33.0
# max                                         684.0                352.0
# mean                                   214.544118           125.220588
# std                                    149.335387            76.434704
# sept                                          489                  208
# oct                                           241                  234
# nov                                            99                  134
# dec                                            68                   61
#
#            Compliance : Install / Rollover Compliance : Configuration / Setup  \
# model                                  mlr                                mlr
# train_rmse                           28.99                              13.82
# test_rmse                            54.25                              10.73
# min                                   30.0                               42.0
# max                                  280.0                              164.0
# mean                            104.720588                          87.705882
# std                              67.240012                          26.948851
# sept                                    78                                 74
# oct                                     75                                 44
# nov                                     42                                 30
# dec                                     37                                 17
#
#            International (US) : Foreign Processing Provision : Federal  \
# model                                      arima-S                 mlr
# train_rmse                                   32.71               13.98
# test_rmse                                    32.03               12.44
# min                                           19.0                24.0
# max                                          220.0               247.0
# mean                                     80.308824           66.014706
# std                                      44.954789           36.106597
# sept                                            97                  51
# oct                                             67                  50
# nov                                             61                  44
# dec                                             53                  37
#
#            Compliance : Import / Export Compliance : Environment Maintenance  \
# model                               mlr                              arima-S
# train_rmse                          9.0                                47.74
# test_rmse                         10.06                                24.59
# min                                11.0                                 14.0
# max                               110.0                                393.0
# mean                          48.514706                            46.867647
# std                           22.153126                            50.457875
# sept                                 32                                   38
# oct                                   9                                   36
# nov                                   7                                   33
# dec                                   3                                   41
#
#            International (US) : Tax Cuts and Jobs Act  \
# model                                             mlr
# train_rmse                                      12.39
# test_rmse                                       13.23
# min                                               0.0
# max                                             334.0
# mean                                        57.203704
# std                                         72.929374
# sept                                               18
# oct                                                18
# nov                                                16
# dec                                                11
#
#            International (US) : Calculation / Posting  \
# model                                         arima-S
# train_rmse                                      21.69
# test_rmse                                       12.03
# min                                               7.0
# max                                             166.0
# mean                                        44.720588
# std                                         31.394859
# sept                                               78
# oct                                                37
# nov                                                21
# dec                                                21
#
#            Provision : Configuration / Setup Provision : State  \
# model                                arima-S               mlr
# train_rmse                             11.99              6.95
# test_rmse                               9.78             10.28
# min                                     18.0               5.0
# max                                    100.0              79.0
# mean                               40.985294         27.955882
# std                                 16.28798         15.411213
# sept                                      32                30
# oct                                       31                33
# nov                                       30                27
# dec                                       32                52
#
#            International (US) : Configuration / Setup
# model                                         arima-S
# train_rmse                                       8.14
# test_rmse                                       10.48
# min                                               7.0
# max                                              52.0
# mean                                        24.602941
# std                                          10.16159
# sept                                               27
# oct                                                20
# nov                                                14
# dec                                                20
