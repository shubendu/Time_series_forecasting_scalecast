# %%
import pandas as pd
import numpy as np
from scalecast.Forecaster import Forecaster
from scalecast.auxmodels import auto_arima
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(14,7)})

# %%
df = pd.read_excel("Case Prediction Data2.xlsx")

# %%
df_comp = df[df["Product"] == "Compliance"]
df_comp.head()
# Out:
#     Case Number                                         Subject  \
# 0        204977                                Efile Acceptance
# 4        204986  LD400 is not reflecting a temporary adjustment
# 6        204992                        Form 2220 Line 19 dates.
# 8        204997                            Corptax Upgrade File
# 10       205001          Share the MSI files for Corptax 2016.2
#
#           Date Created         Date Closed  Origin Priority             Team  \
# 0  2017-01-02 05:39:00 2017-01-03 09:03:00     Web   Medium  Tax Preparation
# 4  2017-01-03 07:17:00 2017-01-05 08:21:00  E-mail   Medium  Tax Preparation
# 6  2017-01-03 07:36:00 2017-01-10 09:16:00     Web   Medium  Tax Preparation
# 8  2017-01-03 08:15:00 2017-01-03 11:36:00     Web   Medium     IT / Systems
# 10 2017-01-03 08:24:00 2017-01-03 11:30:00     Web   Medium     IT / Systems
#
#             Case Type       SLA  \
# 0               Efile  Platinum
# 4     Problem / Error  Platinum
# 6     Problem / Error  Platinum
# 8   Question / How To    Silver
# 10  Question / How To      Gold
#
#                                                                                       Problem Statement  \
# 0       We transmitted a Michigan return still have not received the acceptance/rejection confirmation.
# 4                                                        LD400 is not reflecting a temporary adjustment
# 6   Form 2220 Line 19 dates are repeating. This is a fiscal year client and the quarterly date for p...
# 8                                                                                     provide MSI Files
# 10                                                                                    provide MSI Files
#
#        Product        Product Area                  Product Category  \
# 0   Compliance   Returns / Reports                               NaN
# 4   Compliance   Returns / Reports                               NaN
# 6   Compliance             Amounts                               NaN
# 8   Compliance  Install / Rollover  Provide Corptax Client MSI Files
# 10  Compliance  Install / Rollover  Provide Corptax Client MSI Files
#
#    Product Type Jurisdiction        Resolution             KB #  \
# 0           NaN        US.MI  Answer exists KB  041324813494120
# 4           NaN           US  Answer exists KB  041622907012748
# 6           NaN           US  Answer exists KB  041335414275440
# 8           NaN          NaN  Answer exists KB              NaN
# 10          NaN          NaN  Answer exists KB              NaN
#
#                                                                                                KB Title
# 0                                                            How to understand the Transmission Monitor
# 4   Adjustments do not flow to LD400 workpaper and Taxable income per the LD400 does not tie to the ...
# 6                                          IRS e-Services and Business MeF Maintenance including states
# 8                                                                                                   NaN
# 10                                                                                                  NaN

# %%
#dfc = df[df.Product == "Compliance"]
df_comp['Date Created'] = df_comp['Date Created'].dt.date
df_comp['Date Closed'] = df_comp['Date Closed'].dt.date
df_comp['Date'] = pd.to_datetime(df_comp['Date Created'], errors='coerce')
dfc = df_comp

# %%
# Adding a new column which will have the number of tickets per day
newdf = dfc[["Date","Case Number"]]
newdf.drop_duplicates(inplace=True)
newdf['Date'] = pd.to_datetime(newdf['Date'])
newdf = pd.DataFrame(newdf.groupby([newdf["Date"].dt.date]).count()["Case Number"])
newdf = newdf.reset_index()
newdf.index = newdf.Date
newdf['Date'] = pd.to_datetime(newdf['Date'], errors='coerce')
newdf = newdf.asfreq('D')
newdf = newdf.groupby(pd.Grouper(freq="M")).sum()
newdf
# Out:
#             Case Number
# Date
# 2017-01-31       1066.0
# 2017-02-28       1300.0
# 2017-03-31       2092.0
# 2017-04-30       1247.0
# 2017-05-31       1407.0
# ...                 ...
# 2022-04-30        914.0
# 2022-05-31        777.0
# 2022-06-30        952.0
# 2022-07-31        870.0
# 2022-08-31        581.0
#
# [68 rows x 1 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 68 entries, 2017-01-31 to 2022-08-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Case Number  68 non-null     float64
# dtypes: float64(1)
# memory usage: 1.1 KB

# %%
f = Forecaster(y=newdf['Case Number'],current_dates=newdf.index)
f
# Out:
# Forecaster(
#     DateStartActuals=2017-01-31T00:00:00.000000000
#     DateEndActuals=2022-08-31T00:00:00.000000000
#     Freq=M
#     N_actuals=68
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
#     GridsFile=Grids
# )

# %%
f.generate_future_dates(12)
f.set_test_length(.2)
f.set_estimator('arima')
f.manual_forecast(call_me='arima1')

# %% [markdown]
# # Auto-ARIMA Approach

# %%
auto_arima(
    f,
    start_P=1,
    start_q=1,
    max_p=6,
    max_q=6,
    m=12,
    seasonal=True,
    max_P=4, 
    max_D=4,
    max_Q=4,
    max_d=4,
    trace=True,
    error_action='ignore',
    suppress_warnings=True,
    stepwise=True,
    information_criterion="aic",
    alpha=0.05,
    scoring='mse',
    call_me='arima3',
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=652.143, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=642.270, Time=0.32 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=650.919, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=645.736, Time=0.08 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=643.558, Time=0.64 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=644.076, Time=0.27 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=644.263, Time=0.49 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=640.515, Time=0.56 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=643.747, Time=0.26 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=642.151, Time=1.00 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=inf, Time=1.26 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=641.012, Time=0.32 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=642.421, Time=0.44 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=642.498, Time=0.40 sec
#  ARIMA(0,0,2)(1,1,0)[12] intercept   : AIC=641.539, Time=0.43 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=643.469, Time=0.70 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=638.517, Time=0.37 sec
#  ARIMA(1,0,1)(0,1,0)[12]             : AIC=642.338, Time=0.15 sec
#  ARIMA(1,0,1)(2,1,0)[12]             : AIC=640.152, Time=0.84 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=inf, Time=0.58 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=inf, Time=0.56 sec
#  ARIMA(1,0,1)(2,1,1)[12]             : AIC=inf, Time=1.15 sec
#  ARIMA(0,0,1)(1,1,0)[12]             : AIC=639.015, Time=0.17 sec
#  ARIMA(1,0,0)(1,1,0)[12]             : AIC=640.270, Time=0.14 sec
#  ARIMA(2,0,1)(1,1,0)[12]             : AIC=640.403, Time=0.45 sec
#  ARIMA(1,0,2)(1,1,0)[12]             : AIC=640.473, Time=0.37 sec
#  ARIMA(0,0,0)(1,1,0)[12]             : AIC=642.086, Time=0.09 sec
#  ARIMA(0,0,2)(1,1,0)[12]             : AIC=639.543, Time=0.20 sec
#  ARIMA(2,0,0)(1,1,0)[12]             : AIC=642.263, Time=0.18 sec
#  ARIMA(2,0,2)(1,1,0)[12]             : AIC=641.504, Time=0.52 sec
#
# Best model:  ARIMA(1,0,1)(1,1,0)[12]
# Total fit time: 17.739 seconds

# %%
f.plot_test_set(ci=False,models='arima3')
plt.title('ARIMA Test-Set Performance',size=14)
plt.show()

# %%
f.plot(ci=False,models='arima3')
plt.title('ARIMA Forecast Performance',size=14)
plt.show()

# %%
pd.options.display.max_colwidth = 100
results = f.export(to_excel=True,
                   excel_name='arima_results.xlsx',
                   determine_best_by='TestSetMAPE')

# %%
results["test_set_predictions"]
# Out:
#          DATE  actual       arima3       arima1
# 55 2021-08-31  1517.0  1889.436807  1711.981871
# 56 2021-09-30  2300.0  3386.024467  1711.981871
# 57 2021-10-31  2915.0  4377.117595  1711.981871
# 58 2021-11-30  1417.0  1718.021872  1711.981871
# 59 2021-12-31   710.0   895.707528  1711.981871
# 60 2022-01-31   968.0  1298.928629  1711.981871
# 61 2022-02-28   979.0  1094.670314  1711.981871
# 62 2022-03-31  1157.0  1424.927616  1711.981871
# 63 2022-04-30   914.0  1298.279566  1711.981871
# 64 2022-05-31   777.0   995.411103  1711.981871
# 65 2022-06-30   952.0  1250.822872  1711.981871
# 66 2022-07-31   870.0  1301.247947  1711.981871
# 67 2022-08-31   581.0  1895.557101  1711.981871

# %%
results["all_fcsts"]
# Out:
#          DATE       arima1       arima3
# 0  2022-09-30  1620.819437  1889.421139
# 1  2022-10-31  1620.819437  2733.757837
# 2  2022-11-30  1620.819437  1294.865269
# 3  2022-12-31  1620.819437   619.085756
# 4  2023-01-31  1620.819437   909.955076
# 5  2023-02-28  1620.819437   940.730385
# 6  2023-03-31  1620.819437  1144.475346
# 7  2023-04-30  1620.819437   931.090655
# 8  2023-05-31  1620.819437   790.075445
# 9  2023-06-30  1620.819437   975.325472
# 10 2023-07-31  1620.819437   891.573538
# 11 2023-08-31  1620.819437   703.875850

# %%
f.set_validation_length(12)
grid = {
    'order':[(1,1,1),(1,1,0),(0,1,1)],
    'seasonal_order':[(2,1,1,12),(1,1,1,12),(2,1,0,12),(0,1,0,12)]
}

f.ingest_grid(grid)
f.tune()
f.auto_forecast(call_me='arima4')

f.plot_test_set(ci=False,models='arima4')
plt.title('ARIMA Test-Set Performance',size=14)
plt.show()

f.plot(ci=False,models='arima4')
plt.title('ARIMA Forecast Performance',size=14)
plt.show()

f.regr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   68
# Model:             ARIMA(1, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -408.452
# Date:                            Fri, 26 Aug 2022   AIC                            824.904
# Time:                                    16:51:44   BIC                            832.933
# Sample:                                         0   HQIC                           828.009
#                                              - 68
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2737      0.188     -1.454      0.146      -0.643       0.095
# ar.S.L12       0.3900      0.330      1.182      0.237      -0.257       1.037
# ma.S.L12      -0.9902     10.486     -0.094      0.925     -21.541      19.561
# sigma2      1.333e+05   1.36e+06      0.098      0.922   -2.53e+06     2.8e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.61   Jarque-Bera (JB):                12.44
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                             0.46
# Prob(H) (two-sided):                  0.54   Kurtosis:                         5.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pd.options.display.max_colwidth = 100
results = f.export(to_excel=True,
                   excel_name='arima_results.xlsx',
                   determine_best_by='TestSetMAPE')

# %%
results["test_set_predictions"]
results["all_fcsts"]
# Out:
#          DATE  actual       arima4       arima2       arima3       arima1
# 55 2021-08-31  1517.0  1702.625656  1864.583179  1889.436807  1711.981871
# 56 2021-09-30  2300.0  2582.738084  2511.477406  3386.024467  1711.981871
# 57 2021-10-31  2915.0  3682.114872  3633.539862  4377.117595  1711.981871
# 58 2021-11-30  1417.0  1161.872889  1299.856642  1718.021872  1711.981871
# 59 2021-12-31   710.0   487.171588   655.024484   895.707528  1711.981871
# 60 2022-01-31   968.0   879.611172   972.754895  1298.928629  1711.981871
# 61 2022-02-28   979.0   756.989674   883.125150  1094.670314  1711.981871
# 62 2022-03-31  1157.0  1125.841442  1230.653855  1424.927616  1711.981871
# 63 2022-04-30   914.0   874.646439   942.788336  1298.279566  1711.981871
# 64 2022-05-31   777.0   725.686055   904.774353   995.411103  1711.981871
# 65 2022-06-30   952.0   946.706136  1092.267719  1250.822872  1711.981871
# 66 2022-07-31   870.0  1022.557076  1239.876905  1301.247947  1711.981871
# 67 2022-08-31   581.0  1628.150926  1971.076297  1895.557101  1711.981871

# %%
results["all_fcsts"]
# Out:
#          DATE       arima1       arima2       arima3       arima4
# 0  2022-09-30  1620.819437  1932.067910  1889.421139  1625.693075
# 1  2022-10-31  1620.819437  2981.945128  2733.757837  2382.789529
# 2  2022-11-30  1620.819437   791.024890  1294.865269   430.849719
# 3  2022-12-31  1620.819437   236.550741   619.085756  -235.628436
# 4  2023-01-31  1620.819437   619.801875   909.955076    90.661312
# 5  2023-02-28  1620.819437   525.169692   940.730385    48.910194
# 6  2023-03-31  1620.819437   854.534913  1144.475346   338.270787
# 7  2023-04-30  1620.819437   549.847584   931.090655    62.277341
# 8  2023-05-31  1620.819437   428.037525   790.075445   -64.500533
# 9  2023-06-30  1620.819437   631.389797   975.325472   133.178434
# 10 2023-07-31  1620.819437   717.384464   891.573538   122.255385
# 11 2023-08-31  1620.819437   883.178079   703.875850   250.006508
