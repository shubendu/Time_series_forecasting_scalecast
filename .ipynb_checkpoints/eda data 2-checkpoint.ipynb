# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import warnings
warnings.filterwarnings("ignore")

# Basic
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import os
import random
from tqdm.autonotebook import tqdm
import string
from collections import Counter
import re

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import plotly.express as px

# %matplotlib inline
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_excel("Case Prediction Data2.xlsx")

# %%
df
# Out:
#         Case Number                                            Subject  \
# 0            204977                                   Efile Acceptance
# 1            204979  Oregon STAT help: Previous Case 203787 Client ...
# 2            204980             Data map incorrectly pulling in values
# 3            204981  The New Corptax Connect Website is not properl...
# 4            204986     LD400 is not reflecting a temporary adjustment
# ...             ...                                                ...
# 189183       518074  Possible Wrong Calculation for LA Plaquemines ...
# 189184       518075  Sch. L and M-2 not populating in Short Period ...
# 189185       518076                 Legacy Form 8992 GILTI Calculation
# 189186       518077                VA Efile Diagnostics - not due 8/15
# 189187       518078                          Request Login Credentials
#
#               Date Created         Date Closed  Origin Priority  \
# 0      2017-01-02 05:39:00 2017-01-03 09:03:00     Web   Medium
# 1      2017-01-02 09:03:00 2017-01-04 16:56:00     Web     High
# 2      2017-01-02 11:25:00 2017-01-03 15:48:00     Web   Medium
# 3      2017-01-02 12:06:00 2017-01-03 09:26:00     Web     High
# 4      2017-01-03 07:17:00 2017-01-05 08:21:00  E-mail   Medium
# ...                    ...                 ...     ...      ...
# 189183 2022-08-15 20:04:00 2022-08-16 16:27:00  E-mail   Medium
# 189184 2022-08-15 20:05:00 2022-08-16 17:37:00     Web   Medium
# 189185 2022-08-15 20:22:00 2022-08-16 13:57:00     Web     High
# 189186 2022-08-15 20:45:00 2022-08-17 17:32:00     Web   Medium
# 189187 2022-08-15 22:37:00 2022-08-16 03:44:00     Web      Low
#
#                    Team          Case Type       SLA  \
# 0       Tax Preparation              Efile  Platinum
# 1       Tax Preparation  Question / How To    Silver
# 2       Tax Preparation  Question / How To    Silver
# 3       Tax Preparation    Problem / Error    Silver
# 4       Tax Preparation    Problem / Error  Platinum
# ...                 ...                ...       ...
# 189183  Tax Preparation    Problem / Error    Silver
# 189184  Tax Preparation  Question / How To  Platinum
# 189185  Tax Preparation  Question / How To    Silver
# 189186  Tax Preparation              Efile    Silver
# 189187  Tax Preparation  Question / How To  Platinum
#
#                                         Problem Statement  \
# 0       We transmitted a Michigan return still have no...
# 1       Oregon STAT help: Previous Case 203787 Client ...
# 2       Corptax Office Import - Credit Account imports...
# 3       Searches can't be performed on the new system....
# 4          LD400 is not reflecting a temporary adjustment
# ...                                                   ...
# 189183  In Column B, the total tax due is 12,229.24 (l...
# 189184                      Sch. L and M-2 not populating
# 189185                           Form 8992 US shareholder
# 189186  System will not recognize other subtractions a...
# 189187                          Request Login Credentials
#
#                       Product                               Product Area  \
# 0                  Compliance                          Returns / Reports
# 1                   Provision                                      State
# 2       Office - Excel Add-In                            Import / Export
# 3                    Websites  Connections (https://connect.corptax.com)
# 4                  Compliance                          Returns / Reports
# ...                       ...                                        ...
# 189183              Sales Tax                          Returns / Reports
# 189184             Compliance                          Returns / Reports
# 189185             Compliance                          Returns / Reports
# 189186             Compliance                          Returns / Reports
# 189187               Websites  Connections (https://connect.corptax.com)
#
#                          Product Category Product Type Jurisdiction  \
# 0                                     NaN          NaN        US.MI
# 1                                     NaN          NaN        US.OR
# 2                                     NaN          NaN           US
# 3                           Error Message          NaN          NaN
# 4                                     NaN          NaN           US
# ...                                   ...          ...          ...
# 189183                                NaN          NaN        US.LA
# 189184                                NaN          NaN           US
# 189185                                NaN          NaN           US
# 189186                       Calculations          NaN        US.VA
# 189187  Password Reset - Forgotten/Needed  User Forgot          NaN
#
#                                                Resolution             KB #  \
# 0                                        Answer exists KB  041324813494120
# 1                     Customer no longer needs assistance              NaN
# 2                                        Answer exists KB  041414821333274
# 3                                        Answer exists KB  161216104028927
# 4                                        Answer exists KB  041622907012748
# ...                                                   ...              ...
# 189183  CMD will fix - tax rate update - workaround pr...              NaN
# 189184                                   Answer exists KB  041229318172939
# 189185                             Need more information               NaN
# 189186                                   Answer exists KB  191024105918214
# 189187  Customer, Contact, or Order Record Required Ma...  200907212655307
#
#                                                  KB Title
# 0              How to understand the Transmission Monitor
# 1                                                     NaN
# 2       Corptax® Office - How to place an IF formula i...
# 3       Connections Error - Uh Oh  something went wron...
# 4       Adjustments do not flow to LD400 workpaper and...
# ...                                                   ...
# 189183                                                NaN
# 189184  Form 1120 - Schedule L  Schedule M-1 and Sched...
# 189185                                                NaN
# 189186  VA e-File Error - Schedule 500ADJ  Section B  ...
# 189187            Connections - How to change my password
#
# [189188 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189188 entries, 0 to 189187
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Case Number        189188 non-null  int64
#  1   Subject            189187 non-null  object
#  2   Date Created       189188 non-null  datetime64[ns]
#  3   Date Closed        189142 non-null  datetime64[ns]
#  4   Origin             189188 non-null  object
#  5   Priority           189188 non-null  object
#  6   Team               189186 non-null  object
#  7   Case Type          185597 non-null  object
#  8   SLA                189149 non-null  object
#  9   Problem Statement  185687 non-null  object
#  10  Product            189064 non-null  object
#  11  Product Area       188973 non-null  object
#  12  Product Category   47138 non-null   object
#  13  Product Type       5082 non-null    object
#  14  Jurisdiction       122086 non-null  object
#  15  Resolution         186118 non-null  object
#  16  KB #               51891 non-null   object
#  17  KB Title           49853 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(15)
# memory usage: 26.0+ MB

# %% [markdown]
# ### Total Time to resolve the issue

# %%
df['Date Created'] = df['Date Created'].dt.date
df['Date Closed'] = df['Date Closed'].dt.date

# %%
df["total_time"] = df["Date Closed"] - df["Date Created"]

# %%
df["total_time"].value_counts()[:15]
# Out:
# 0 days     96930
# 1 days     39827
# 2 days     11067
# 3 days      9424
# 4 days      6200
# 5 days      4797
# 6 days      4283
# 7 days      3653
# 8 days      2070
# 9 days      1107
# 10 days      857
# 13 days      803
# 11 days      800
# 14 days      712
# 12 days      698
# Name: total_time, dtype: int64

# %%
df["total_time"].value_counts()[-15:]
# Out:
# 275 days    1
# 555 days    1
# 657 days    1
# 276 days    1
# 202 days    1
# 374 days    1
# 433 days    1
# 326 days    1
# 292 days    1
# 575 days    1
# 581 days    1
# 565 days    1
# 709 days    1
# 317 days    1
# 371 days    1
# Name: total_time, dtype: int64

# %% [markdown]
# - Insights: Most of the tasks were resolved quickly but few tasks took almost year to complete

# %%
df.isnull().sum()
# Out:
# Case Number               0
# Subject                   1
# Date Created              0
# Date Closed              46
# Origin                    0
# Priority                  0
# Team                      2
# Case Type              3591
# SLA                      39
# Problem Statement      3501
# Product                 124
# Product Area            215
# Product Category     142050
# Product Type         184106
# Jurisdiction          67102
# Resolution             3070
# KB #                 137297
# KB Title             139335
# dtype: int64

# %%
missing_values = df.isna().sum()
px.bar(missing_values,
       x=missing_values.index,
       y=missing_values.values,
       title="Missing Values",
       labels=dict(x="Variable", y="Missing Values"), template='plotly_dark')
# Out:
# <div>                            <div id="1959f421-d002-4b96-a7ee-cc3379d135c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1959f421-d002-4b96-a7ee-cc3379d135c2")) {                    Plotly.newPlot(                        "1959f421-d002-4b96-a7ee-cc3379d135c2",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Missing Values=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Case Number","Subject","Date Created","Date Closed","Origin","Priority","Team","Case Type","SLA","Problem Statement","Product","Product Area","Product Category","Product Type","Jurisdiction","Resolution","KB #","KB Title"],"xaxis":"x","y":[0,1,0,46,0,0,2,3591,39,3501,124,215,142050,184106,67102,3070,137297,139335],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"t ...

# %% [markdown]
# - Insight: Product Category, Product Type, KB# and KB Title has the missing value of more than 60%

# %%
len(df.Subject.value_counts())
# Out:
# 157484

# %%
typecounts = df.Origin.value_counts().to_dict()
df1 = pd.DataFrame(list(typecounts.items()), columns=['Origin', 'Counts'])

fig = px.pie(df1, values='Counts', names='Origin',
             title='Origin',labels='Origin')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="e3453472-93b1-4205-b719-82f1c8814283" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3453472-93b1-4205-b719-82f1c8814283")) {                    Plotly.newPlot(                        "e3453472-93b1-4205-b719-82f1c8814283",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Origin=%{label}<br>Counts=%{value}<extra></extra>","labels":["Web","Phone","E-mail","Other / Internal Request","Community"],"legendgroup":"","name":"","showlegend":true,"values":[161754,12442,7498,7375,119],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewi ...
#
# var gd = document.getElementByI

# %% [markdown]
# - Insights: Most of the origin of the problem is related to Web

# %%
typecounts = df["Case Type"].value_counts().to_dict()
df1 = pd.DataFrame(list(typecounts.items()), columns=['Case_type', 'Counts'])

fig = px.pie(df1, values='Counts', names='Case_type',
             title='Case Type',labels='Case_type')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="a43d7ff1-5b47-4336-a61a-60b866ffee15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a43d7ff1-5b47-4336-a61a-60b866ffee15")) {                    Plotly.newPlot(                        "a43d7ff1-5b47-4336-a61a-60b866ffee15",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Case_type=%{label}<br>Counts=%{value}<extra></extra>","labels":["Question / How To","Problem / Error","Efile","Concern","Installation / Upgrade","Database Restore","Enhancement Request"],"legendgroup":"","name":"","showlegend":true,"values":[93537,43945,29593,13159,2971,1561,831],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# - Insights: Most of the problems are regarding "How to solve it"

# %%
typecounts = df["SLA"].value_counts().to_dict()
df1 = pd.DataFrame(list(typecounts.items()), columns=['SLA', 'Counts'])

fig = px.pie(df1, values='Counts', names='SLA',
             title='SLA',labels='SLA')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="89291736-f494-49cf-8a9b-e995b8cf808b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89291736-f494-49cf-8a9b-e995b8cf808b")) {                    Plotly.newPlot(                        "89291736-f494-49cf-8a9b-e995b8cf808b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"SLA=%{label}<br>Counts=%{value}<extra></extra>","labels":["Silver","Platinum","Gold","Client Loss","Billable Support","Default"],"legendgroup":"","name":"","showlegend":true,"values":[136326,45219,7426,175,2,1],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outli ...
#
# var gd = document.getElementBy

# %%
typecounts = df["Product"].value_counts().to_dict()
df1 = pd.DataFrame(list(typecounts.items()), columns=['Product', 'Counts'])

fig = px.pie(df1, values='Counts', names='Product',
             title='Product',labels='Product')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="3c5ca94e-6aa1-4ce6-95d7-da5f0d1e2cee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c5ca94e-6aa1-4ce6-95d7-da5f0d1e2cee")) {                    Plotly.newPlot(                        "3c5ca94e-6aa1-4ce6-95d7-da5f0d1e2cee",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Product=%{label}<br>Counts=%{value}<extra></extra>","labels":["Compliance","International (US)","Websites","Provision","Partnership / S Corp / Pass-Through","Sales Tax","Office - Excel Add-In","Application Hosting","Other","Calendar","Data Exchange Manager","WorkSpace","ODBC Driver - Corptax","Web Services","Claims"],"legendgroup":"","name":"","showlegend":true,"values":[110216,28604,16459,9918,9069,4338,3799,3440,798,768,570,529,300,199,57],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width": ...

# %%
typecounts = df["Priority"].value_counts().to_dict()
df1 = pd.DataFrame(list(typecounts.items()), columns=['Priority', 'Counts'])

fig = px.pie(df1, values='Counts', names='Priority',
             title='Priority',labels='Priority')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="df80e7f7-2143-4b26-b436-725bd739cf47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df80e7f7-2143-4b26-b436-725bd739cf47")) {                    Plotly.newPlot(                        "df80e7f7-2143-4b26-b436-725bd739cf47",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Priority=%{label}<br>Counts=%{value}<extra></extra>","labels":["Medium","High","Low","Critical"],"legendgroup":"","name":"","showlegend":true,"values":[125575,30822,16464,16327],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histog ...
#
# var gd = document.getElementById('df80e7f7-2143-4b26-b436-

# %%
typecounts = df["Product"].value_counts()
typecounts = pd.DataFrame(typecounts).reset_index()
fig = px.bar(typecounts, 
             x="index", 
             y="Product",  
             title="Frequency of Product",
             color_discrete_sequence=["#DC143C"], template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="67c60f98-8780-492c-95ef-a4e72921ea34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67c60f98-8780-492c-95ef-a4e72921ea34")) {                    Plotly.newPlot(                        "67c60f98-8780-492c-95ef-a4e72921ea34",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Product=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#DC143C","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Compliance","International (US)","Websites","Provision","Partnership / S Corp / Pass-Through","Sales Tax","Office - Excel Add-In","Application Hosting","Other","Calendar","Data Exchange Manager","WorkSpace","ODBC Driver - Corptax","Web Services","Claims"],"xaxis":"x","y":[110216,28604,16459,9918,9069,4338,3799,3440,798,768,570,529,300,199,57],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinew ...

# %%
typecounts = df["Team"].value_counts()
typecounts = pd.DataFrame(typecounts).reset_index()
fig = px.bar(typecounts, 
             x="index", 
             y="Team",  
             title="Frequency of Resolution",
             color_discrete_sequence=["#DC143C"], template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="01232564-95da-4756-af92-13fdd562b71b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01232564-95da-4756-af92-13fdd562b71b")) {                    Plotly.newPlot(                        "01232564-95da-4756-af92-13fdd562b71b",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Team=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#DC143C","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tax Preparation","IT / Systems","Implementation","Customer Operations","Automated Processing","Trainers","Security Assessment","TCI Only - Support","Training Coordinators","Voice Mail"],"xaxis":"x","y":[166108,17456,1901,1469,1332,866,28,13,11,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %%
typecounts = df["Product Area"].value_counts()
typecounts = pd.DataFrame(typecounts).reset_index()
fig = px.bar(typecounts, 
             x="index", 
             y="Product Area",  
             title="Frequency of Product Area",
             color_discrete_sequence=["#DC143C"], template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="1b788b33-170b-4bb8-9dcc-d39a64fcd77e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b788b33-170b-4bb8-9dcc-d39a64fcd77e")) {                    Plotly.newPlot(                        "1b788b33-170b-4bb8-9dcc-d39a64fcd77e",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Product Area=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#DC143C","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Returns / Reports","Connections (https://connect.corptax.com)","Configuration / Setup","Amounts","Install / Rollover","Foreign Processing","Import / Export","Federal","Environment Maintenance","Tax Cuts and Jobs Act","Calculation / Posting","State","Maintenance","Printing","BEPS CbC","K1 Data","Backup / Restore","Functions","Domestic Processing","Excel Templates","Allocate","Data Connections","Install","Setup","Login","Global Calendar","Error Messages","Other","System Requirements","Processing","Trainer on Call","Entity Obligations","Import","K2/K3","Data Profile","Corptax (http://www.corptax.com)","Library / List","File Transfer Service (https://transfer.corptax.com)","Tax Contingency (FIN48)","iConnect (https://iconnect.corptax.com)","Error","Transmission Monitor","FS/CS or CORPInternational","Connection","Dashboard / Reports","Visual Org","ETS","Security Assessment","Transfer Pricing Architect","Office Exel Add-in","Publish","Wall of Feedback (https://corptax.ideascale.com)","TPS","Search","Expired Certificate","Provide Renewed Certificate","Global Minimum Tax (GMT)"],"xaxis":"x","y":[100282,15935,11228,8931,7792,5419,5409,4456,3912,3541,2996,1886,1582,1386,1337,1272,949,889,711,698,694,652,647,565,556,519,474,473,453,406,355,318,295,259,209,198,187,173,156,117,113,112,94,89,48,40,40,26,23,23,16,11,9,6,4,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7 ...

# %%
typecounts = df["Resolution"].value_counts()
typecounts = pd.DataFrame(typecounts).reset_index()
fig = px.bar(typecounts, 
             x="index", 
             y="Resolution",  
             title="Frequency of Resolution",
             color_discrete_sequence=["#DC143C"], template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="6fe74b0c-ed06-481b-a5d5-611fb805bc52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fe74b0c-ed06-481b-a5d5-611fb805bc52")) {                    Plotly.newPlot(                        "6fe74b0c-ed06-481b-a5d5-611fb805bc52",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Resolution=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#DC143C","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Answer exists KB","Answer exists Help","Provide solution - no KB required (e.g. client specific)","Customer no longer needs assistance","Customer, Contact, or Order Record Required Maintenance","Need more information ","Create/Update KB","Answer exists form preparation guidelines","Walk through","Duplicate case","Case attached to Issue","SaaS service request completed","VSTS - Bug","Resolved by Enterprise Technology","Needed latest version calc/collateral","Defect - Calc Definition","Working as Designed - More info needed from L3 for KB","Unique Work-Around Accepted","Process to have collateral published","Answer exists form tool tip or note","Defect - Dataspec","Defect - Calc map error","Provided backup","Database Restore Completed","VSTS - PBI","Remove stuck data Rname field","Provisioned environment","Answer exists jurisdictional form instructions","Defect - Collateral error","Working as Designed - CMD is not making changes","Learning Inquiry","Performed upgrade","Client specific question that only CMD can answer","SaaS incident","Installation/Upgrade completed","Defect - Cobol","Override removed","Known Issue - provide info from previous cases, KB requested","Reviewed issue, no further escalation required","VSTS Created - Bug","Environment Maintenance Inquiry","Provide solution - technical documentation update required","Enhancement - Other","Workaround Provided - CMD is not going to change the calc","Enhancement - Dataspec","No workaround - Jurisdiction contacted","Needs training","Defect - Other","Workaround - VSTS - NO","VSTS - DECLINED","CMD will fix - tax rate update - workaround provided","Transferred to Deloitte - security request","CMD will fix - in a future release - Date TBD","Enhancement request - Add functionality","Enhancement - Deferred to next year","Issue no longer exists (for escalations only)","Create/Update Help","Workaround - VSTS - Bug","Enhancement - Calc Definition","Working as Designed - Information was available in the KB or instructions","Enhancement request - New Form Request","CMD will fix - logic error - workaround provided","SSAE Report Request","Transferred to Deloitte - question regarding Deloitte app/process","Resolved by creating a new return item","VSTS - Feature","VSTS Created - Root Cause Analysis","Customer asking for tax advice","Resolved by 3rd party vendor","Defect - Other e-File error","CMD will fix next year - logic error - workaround provided for current year","Enhancement - Option","Process for adding Jurisdiction","Workaround - VSTS - PBI","Reset admin password","Reviewed issue, No action by SaaS required","Publishing Error","Defect - DRY - Form","Defect - Descriptive","Create/Update form preparation guidelines","Defect - eFile","Defect - DRY - Input Field","CMD will fix - New Law/Change in Law - no workaround provided or needed","Defect - Perform Statement","Defect - Form - HPL","Enhancement - Form Request","Defect - Help File","Defect - Printing","CMD will fix - logic error - no workaround provided","Enhancement - Cobol","RFP Request","Transferred to Deloitte - collateral load","Performed restore of customer production environment","Defect - Filing Instructions","CMD will fix - New Law/Change in Law - workaroun ...

# %% [markdown]
# # Text Preprocessing

# %%
df1 = df[["Problem Statement","Subject"]]
df1
# Out:
#                                         Problem Statement  \
# 0       We transmitted a Michigan return still have no...
# 1       Oregon STAT help: Previous Case 203787 Client ...
# 2       Corptax Office Import - Credit Account imports...
# 3       Searches can't be performed on the new system....
# 4          LD400 is not reflecting a temporary adjustment
# ...                                                   ...
# 189183  In Column B, the total tax due is 12,229.24 (l...
# 189184                      Sch. L and M-2 not populating
# 189185                           Form 8992 US shareholder
# 189186  System will not recognize other subtractions a...
# 189187                          Request Login Credentials
#
#                                                   Subject
# 0                                        Efile Acceptance
# 1       Oregon STAT help: Previous Case 203787 Client ...
# 2                  Data map incorrectly pulling in values
# 3       The New Corptax Connect Website is not properl...
# 4          LD400 is not reflecting a temporary adjustment
# ...                                                   ...
# 189183  Possible Wrong Calculation for LA Plaquemines ...
# 189184  Sch. L and M-2 not populating in Short Period ...
# 189185                 Legacy Form 8992 GILTI Calculation
# 189186                VA Efile Diagnostics - not due 8/15
# 189187                          Request Login Credentials
#
# [189188 rows x 2 columns]

# %%
df1.isnull().sum()
# Out:
# Problem Statement    3501
# Subject                 1
# dtype: int64

# %%
df1.shape
# Out:
# (189188, 2)

# %%
df1 = df1.dropna(axis=0)
df1.shape
# Out:
# (185687, 2)

# %%
stemmer = SnowballStemmer('english')
stop_words = set(stopwords.words("english"))
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import re
def review_to_words(raw_review):
    # 1. Delete HTML 
    review_text = BeautifulSoup(raw_review, 'html.parser').get_text()
    # 2. Make a space
    letters_only = re.sub('[^a-zA-Z]', ' ', review_text)
    # 3. lower letters
    words = letters_only.lower().split()
    # 5. Stopwords 
    meaningful_words = [w for w in words if not w in stop_words]
    # 6. lemmatize
    lemmas = [lemmatizer.lemmatize(word, pos ='v') for word in meaningful_words]
    # 7. space join words
    return( ' '.join(lemmas))

# %%
# %time df1['clean_statement'] = df1["Problem Statement"].apply(review_to_words)
# Out:
# Wall time: 15.6 s

# %%
# %time df1['clean_subject'] = df1["Subject"].apply(review_to_words)
# Out:
# Wall time: 13.2 s

# %%
df1
# Out:
#                                         Problem Statement  \
# 0       We transmitted a Michigan return still have no...
# 1       Oregon STAT help: Previous Case 203787 Client ...
# 2       Corptax Office Import - Credit Account imports...
# 3       Searches can't be performed on the new system....
# 4          LD400 is not reflecting a temporary adjustment
# ...                                                   ...
# 189183  In Column B, the total tax due is 12,229.24 (l...
# 189184                      Sch. L and M-2 not populating
# 189185                           Form 8992 US shareholder
# 189186  System will not recognize other subtractions a...
# 189187                          Request Login Credentials
#
#                                                   Subject  \
# 0                                        Efile Acceptance
# 1       Oregon STAT help: Previous Case 203787 Client ...
# 2                  Data map incorrectly pulling in values
# 3       The New Corptax Connect Website is not properl...
# 4          LD400 is not reflecting a temporary adjustment
# ...                                                   ...
# 189183  Possible Wrong Calculation for LA Plaquemines ...
# 189184  Sch. L and M-2 not populating in Short Period ...
# 189185                 Legacy Form 8992 GILTI Calculation
# 189186                VA Efile Diagnostics - not due 8/15
# 189187                          Request Login Credentials
#
#                                           clean_statement  \
# 0       transmit michigan return still receive accepta...
# 1       oregon stat help previous case client need hel...
# 2       corptax office import credit account import po...
# 3       search perform new system function properly si...
# 4                         ld reflect temporary adjustment
# ...                                                   ...
# 189183  column b total tax due line discount tax due c...
# 189184                                     sch l populate
# 189185                                form us shareholder
# 189186  system recognize subtractions create diagnosti...
# 189187                          request login credentials
#
#                                             clean_subject
# 0                                        efile acceptance
# 1       oregon stat help previous case client need hel...
# 2                         data map incorrectly pull value
# 3               new corptax connect website properly work
# 4                         ld reflect temporary adjustment
# ...                                                   ...
# 189183  possible wrong calculation la plaquemines pari...
# 189184                 sch l populate short period return
# 189185                      legacy form gilti calculation
# 189186                           va efile diagnostics due
# 189187                          request login credentials
#
# [185687 rows x 4 columns]

# %%
word_count = [len(x.split()) for x in df1['Problem Statement'].tolist()]
barplot_dim = (12, 6)
ax = plt.subplots(figsize =barplot_dim);
ax = sns.distplot(word_count, kde=False);
ax.set_ylabel('No. of Observations', size=15)
ax.set_xlabel('No. of Words', size=15)
ax.set_title('Problem Statement Word Count Distribution', size=20);

# %%
word_count = [len(x.split()) for x in df1['clean_statement'].tolist()]
barplot_dim = (12, 6)
ax = plt.subplots(figsize =barplot_dim);
ax = sns.distplot(word_count, kde=False);
ax.set_ylabel('No. of Observations', size=15)
ax.set_xlabel('No. of Words', size=15)
ax.set_title('Clean Problem Statement Word Count Distribution', size=20);

# %%
word_count = [len(x.split()) for x in df1['Subject'].tolist()]
barplot_dim = (12, 6)
ax = plt.subplots(figsize =barplot_dim);
ax = sns.distplot(word_count, kde=False);
ax.set_ylabel('No. of Observations', size=15)
ax.set_xlabel('No. of Words', size=15)
ax.set_title('Subject Word Count Distribution', size=20);

# %%
word_count = [len(x.split()) for x in df1['clean_subject'].tolist()]
barplot_dim = (12, 6)
ax = plt.subplots(figsize =barplot_dim);
ax = sns.distplot(word_count, kde=False);
ax.set_ylabel('No. of Observations', size=15)
ax.set_xlabel('No. of Words', size=15)
ax.set_title('Clean Subject Word Count Distribution', size=20);

# %% [markdown]
# ## Most Frequent words in Problem Statement

# %%
temp_df = pd.DataFrame()
df1['temp_list'] = df1['clean_statement'].apply(lambda x :str(x).split())
top = Counter([item for sublist in df1['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp.columns = ['Common Words', 'Count']
temp.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_73ad8_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_73ad8_row1_col1 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_73ad8_row2_col1 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_73ad8_row3_col1 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_73ad8_row4_col1, #T_73ad8_row5_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_73ad8_row6_col1 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_73ad8_row7_col1 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_73ad8_row8_col1 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_73ad8_row9_col1 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_73ad8_row10_col1 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_73ad8_row11_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_73ad8_row12_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_73ad8_row13_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_73ad8_row14_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_73ad8_row15_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_73ad8_row16_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_73ad8_row17_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_73ad8_row18_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_73ad8_row19_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_73ad8_row20_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_73ad8_row21_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_73ad8_row22_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_73ad8_row23_col1, #T_73ad8_row24_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_73ad8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73ad8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73ad8_row0_col0" class="data row0 col0" >return</td>
#       <td id="T_73ad8_row0_col1" class="data row0 col1" >30642</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73ad8_row1_col0" class="data row1 col0" >form</td>
#       <td id="T_73ad8_row1_col1" class="data row1 col1" >29680</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73ad8_row2_col0" class="data row2 col0" >file</td>
#       <td id="T_73ad8_row2_col1" class="data row2 col1" >25044</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73ad8_row3_col0" class="data row3 col0" >e</td>
#       <td id="T_73ad8_row3_col1" class="data row3 col1" >22820</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73ad8_row4_col0" class="data row4 col0" >schedule</td>
#       <td id="T_73ad8_row4_col1" class="data row4 col1" >16707</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73ad8_row5_col0" class="data row5 col0" >error</td>
#       <td id="T_73ad8_row5_col1" class="data row5 col1" >16691</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73ad8_row6_col0" class="data row6 col0" >line</td>
#       <td id="T_73ad8_row6_col1" class="data row6 col1" >15982</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73ad8_row7_col0" class="data row7 col0" >tax</td>
#       <td id="T_73ad8_row7_col1" class="data row7 col1" >15464</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_73ad8_row8_col0" class="data row8 col0" >corptax</td>
#       <td id="T_73ad8_row8_col1" class="data row8 col1" >15053</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_73ad8_row9_col0" class="data row9 col0" >amount</td>
#       <td id="T_73ad8_row9_col1" class="data row9 col1" >14304</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_73ad8_row10_col0" class="data row10 col0" >need</td>
#       <td id="T_73ad8_row10_col1" class="data row10 col1" >13478</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_73ad8_row11_col0" class="data row11 col0" >report</td>
#       <td id="T_73ad8_row11_col1" class="data row11 col1" >11955</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_73ad8_row12_col0" class="data row12 col0" >populate</td>
#       <td id="T_73ad8_row12_col1" class="data row12 col1" >10399</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_73ad8_row13_col0" class="data row13 col0" >request</td>
#       <td id="T_73ad8_row13_col1" class="data row13 col1" >10261</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_73ad8_row14_col0" class="data row14 col0" >data</td>
#       <td id="T_73ad8_row14_col1" class="data row14 col1" >9927</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_73ad8_row15_col0" class="data row15 col0" >entity</td>
#       <td id="T_73ad8_row15_col1" class="data row15 col1" >9534</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_73ad8_row16_col0" class="data row16 col0" >state</td>
#       <td id="T_73ad8_row16_col1" class="data row16 col1" >9224</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_73ad8_row17_col0" class="data row17 col0" >sch</td>
#       <td id="T_73ad8_row17_col1" class="data row17 col1" >8294</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_73ad8_row18_col0" class="data row18 col0" >get</td>
#       <td id="T_73ad8_row18_col1" class="data row18 col1" >8161</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_73ad8_row19_col0" class="data row19 col0" >efile</td>
#       <td id="T_73ad8_row19_col1" class="data row19 col1" >7801</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_73ad8_row20_col0" class="data row20 col0" >group</td>
#       <td id="T_73ad8_row20_col1" class="data row20 col1" >7241</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_73ad8_row21_col0" class="data row21 col0" >account</td>
#       <td id="T_73ad8_row21_col1" class="data row21 col1" >7091</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_73ad8_row22_col0" class="data row22 col0" >login</td>
#       <td id="T_73ad8_row22_col1" class="data row22 col1" >7013</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_73ad8_row23_col0" class="data row23 col0" >income</td>
#       <td id="T_73ad8_row23_col1" class="data row23 col1" >6951</td>
#     </tr>
#     <tr>
#       <th id="T_73ad8_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_73ad8_row24_col0" class="data row24 col0" >assistance</td>
#       <td id="T_73ad8_row24_col1" class="data row24 col1" >6903</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Most Frequent words in Subject

# %%
temp_df = pd.DataFrame()
df1['temp_list'] = df1['clean_subject'].apply(lambda x :str(x).split())
top = Counter([item for sublist in df1['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp.columns = ['Common Words', 'Count']
temp.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_7de37_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_7de37_row1_col1 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_7de37_row2_col1 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_7de37_row3_col1 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_7de37_row4_col1 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_7de37_row5_col1 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_7de37_row6_col1 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_7de37_row7_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_7de37_row8_col1, #T_7de37_row9_col1, #T_7de37_row10_col1 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_7de37_row11_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_7de37_row12_col1 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_7de37_row13_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_7de37_row14_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_7de37_row15_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_7de37_row16_col1 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_7de37_row17_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_7de37_row18_col1, #T_7de37_row19_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_7de37_row20_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_7de37_row21_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_7de37_row22_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_7de37_row23_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_7de37_row24_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_7de37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common Words</th>
#       <th class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7de37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7de37_row0_col0" class="data row0 col0" >form</td>
#       <td id="T_7de37_row0_col1" class="data row0 col1" >25088</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7de37_row1_col0" class="data row1 col0" >e</td>
#       <td id="T_7de37_row1_col1" class="data row1 col1" >20092</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7de37_row2_col0" class="data row2 col0" >return</td>
#       <td id="T_7de37_row2_col1" class="data row2 col1" >19917</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7de37_row3_col0" class="data row3 col0" >file</td>
#       <td id="T_7de37_row3_col1" class="data row3 col1" >19577</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7de37_row4_col0" class="data row4 col0" >error</td>
#       <td id="T_7de37_row4_col1" class="data row4 col1" >15818</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7de37_row5_col0" class="data row5 col0" >request</td>
#       <td id="T_7de37_row5_col1" class="data row5 col1" >14285</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7de37_row6_col0" class="data row6 col0" >login</td>
#       <td id="T_7de37_row6_col1" class="data row6 col1" >13113</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7de37_row7_col0" class="data row7 col0" >tax</td>
#       <td id="T_7de37_row7_col1" class="data row7 col1" >13029</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7de37_row8_col0" class="data row8 col0" >schedule</td>
#       <td id="T_7de37_row8_col1" class="data row8 col1" >12485</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7de37_row9_col0" class="data row9 col0" >corptax</td>
#       <td id="T_7de37_row9_col1" class="data row9 col1" >12471</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7de37_row10_col0" class="data row10 col0" >credentials</td>
#       <td id="T_7de37_row10_col1" class="data row10 col1" >12459</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7de37_row11_col0" class="data row11 col0" >efile</td>
#       <td id="T_7de37_row11_col1" class="data row11 col1" >9919</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7de37_row12_col0" class="data row12 col0" >report</td>
#       <td id="T_7de37_row12_col1" class="data row12 col1" >8862</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7de37_row13_col0" class="data row13 col0" >sch</td>
#       <td id="T_7de37_row13_col1" class="data row13 col1" >7823</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7de37_row14_col0" class="data row14 col0" >issue</td>
#       <td id="T_7de37_row14_col1" class="data row14 col1" >7448</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7de37_row15_col0" class="data row15 col0" >state</td>
#       <td id="T_7de37_row15_col1" class="data row15 col1" >7195</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7de37_row16_col0" class="data row16 col0" >line</td>
#       <td id="T_7de37_row16_col1" class="data row16 col1" >6837</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7de37_row17_col0" class="data row17 col0" >need</td>
#       <td id="T_7de37_row17_col1" class="data row17 col1" >6394</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7de37_row18_col0" class="data row18 col0" >amount</td>
#       <td id="T_7de37_row18_col1" class="data row18 col1" >6199</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7de37_row19_col0" class="data row19 col0" >data</td>
#       <td id="T_7de37_row19_col1" class="data row19 col1" >6141</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7de37_row20_col0" class="data row20 col0" >errors</td>
#       <td id="T_7de37_row20_col1" class="data row20 col1" >5580</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7de37_row21_col0" class="data row21 col0" >entity</td>
#       <td id="T_7de37_row21_col1" class="data row21 col1" >5243</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7de37_row22_col0" class="data row22 col0" >populate</td>
#       <td id="T_7de37_row22_col1" class="data row22 col1" >5131</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7de37_row23_col0" class="data row23 col0" >income</td>
#       <td id="T_7de37_row23_col1" class="data row23 col1" >4828</td>
#     </tr>
#     <tr>
#       <th id="T_7de37_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7de37_row24_col0" class="data row24 col0" >year</td>
#       <td id="T_7de37_row24_col1" class="data row24 col1" >4602</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Word Cloud of Problem Statement

# %%
text = ' '.join(df1['clean_statement'])
wordcloud = WordCloud(background_color='white', stopwords=STOPWORDS, width=2560, height=1440).generate(text)

barplot_dim = (15, 15)
ax = plt.subplots(figsize=barplot_dim, facecolor='w')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Word Cloud of Subject

# %%
text = ' '.join(df1['clean_subject'])
wordcloud = WordCloud(background_color='white', stopwords=STOPWORDS, width=2560, height=1440).generate(text)

barplot_dim = (15, 15)
ax = plt.subplots(figsize=barplot_dim, facecolor='w')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
