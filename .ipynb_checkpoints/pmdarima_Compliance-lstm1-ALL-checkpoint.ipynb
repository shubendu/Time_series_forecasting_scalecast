# %%
import pandas as pd
import numpy as np
from scalecast.Forecaster import Forecaster
from scalecast.auxmodels import auto_arima
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(14,7)})

# %%
df = pd.read_excel("Case Prediction Data2.xlsx")
df.head()
# Out:
#    Case Number                                            Subject  \
# 0       204977                                   Efile Acceptance
# 1       204979  Oregon STAT help: Previous Case 203787 Client ...
# 2       204980             Data map incorrectly pulling in values
# 3       204981  The New Corptax Connect Website is not properl...
# 4       204986     LD400 is not reflecting a temporary adjustment
#
#          Date Created         Date Closed  Origin Priority             Team  \
# 0 2017-01-02 05:39:00 2017-01-03 09:03:00     Web   Medium  Tax Preparation
# 1 2017-01-02 09:03:00 2017-01-04 16:56:00     Web     High  Tax Preparation
# 2 2017-01-02 11:25:00 2017-01-03 15:48:00     Web   Medium  Tax Preparation
# 3 2017-01-02 12:06:00 2017-01-03 09:26:00     Web     High  Tax Preparation
# 4 2017-01-03 07:17:00 2017-01-05 08:21:00  E-mail   Medium  Tax Preparation
#
#            Case Type       SLA  \
# 0              Efile  Platinum
# 1  Question / How To    Silver
# 2  Question / How To    Silver
# 3    Problem / Error    Silver
# 4    Problem / Error  Platinum
#
#                                    Problem Statement                Product  \
# 0  We transmitted a Michigan return still have no...             Compliance
# 1  Oregon STAT help: Previous Case 203787 Client ...              Provision
# 2  Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 3  Searches can't be performed on the new system....               Websites
# 4     LD400 is not reflecting a temporary adjustment             Compliance
#
#                                 Product Area Product Category Product Type  \
# 0                          Returns / Reports              NaN          NaN
# 1                                      State              NaN          NaN
# 2                            Import / Export              NaN          NaN
# 3  Connections (https://connect.corptax.com)    Error Message          NaN
# 4                          Returns / Reports              NaN          NaN
#
#   Jurisdiction                           Resolution             KB #  \
# 0        US.MI                     Answer exists KB  041324813494120
# 1        US.OR  Customer no longer needs assistance              NaN
# 2           US                     Answer exists KB  041414821333274
# 3          NaN                     Answer exists KB  161216104028927
# 4           US                     Answer exists KB  041622907012748
#
#                                             KB Title
# 0         How to understand the Transmission Monitor
# 1                                                NaN
# 2  Corptax® Office - How to place an IF formula i...
# 3  Connections Error - Uh Oh  something went wron...
# 4  Adjustments do not flow to LD400 workpaper and...

# %%
df_comp = df
df_comp.head()
# Out:
#    Case Number                                            Subject  \
# 0       204977                                   Efile Acceptance
# 1       204979  Oregon STAT help: Previous Case 203787 Client ...
# 2       204980             Data map incorrectly pulling in values
# 3       204981  The New Corptax Connect Website is not properl...
# 4       204986     LD400 is not reflecting a temporary adjustment
#
#   Date Created Date Closed  Origin Priority             Team  \
# 0   2017-01-02  2017-01-03     Web   Medium  Tax Preparation
# 1   2017-01-02  2017-01-04     Web     High  Tax Preparation
# 2   2017-01-02  2017-01-03     Web   Medium  Tax Preparation
# 3   2017-01-02  2017-01-03     Web     High  Tax Preparation
# 4   2017-01-03  2017-01-05  E-mail   Medium  Tax Preparation
#
#            Case Type       SLA  \
# 0              Efile  Platinum
# 1  Question / How To    Silver
# 2  Question / How To    Silver
# 3    Problem / Error    Silver
# 4    Problem / Error  Platinum
#
#                                    Problem Statement                Product  \
# 0  We transmitted a Michigan return still have no...             Compliance
# 1  Oregon STAT help: Previous Case 203787 Client ...              Provision
# 2  Corptax Office Import - Credit Account imports...  Office - Excel Add-In
# 3  Searches can't be performed on the new system....               Websites
# 4     LD400 is not reflecting a temporary adjustment             Compliance
#
#                                 Product Area Product Category Product Type  \
# 0                          Returns / Reports              NaN          NaN
# 1                                      State              NaN          NaN
# 2                            Import / Export              NaN          NaN
# 3  Connections (https://connect.corptax.com)    Error Message          NaN
# 4                          Returns / Reports              NaN          NaN
#
#   Jurisdiction                           Resolution             KB #  \
# 0        US.MI                     Answer exists KB  041324813494120
# 1        US.OR  Customer no longer needs assistance              NaN
# 2           US                     Answer exists KB  041414821333274
# 3          NaN                     Answer exists KB  161216104028927
# 4           US                     Answer exists KB  041622907012748
#
#                                             KB Title       Date
# 0         How to understand the Transmission Monitor 2017-01-02
# 1                                                NaN 2017-01-02
# 2  Corptax® Office - How to place an IF formula i... 2017-01-02
# 3  Connections Error - Uh Oh  something went wron... 2017-01-02
# 4  Adjustments do not flow to LD400 workpaper and... 2017-01-03

# %%
#dfc = df[df.Product == "Compliance"]
# df_comp['Date Created'] = df_comp['Date Created'].dt.date
# df_comp['Date Closed'] = df_comp['Date Closed'].dt.date
df_comp['Date'] = pd.to_datetime(df_comp['Date Created'], errors='coerce')
dfc = df_comp

# %%
# Adding a new column which will have the number of tickets per day
newdf = dfc[["Date","Case Number"]]
newdf.drop_duplicates(inplace=True)
newdf['Date'] = pd.to_datetime(newdf['Date'])
newdf = pd.DataFrame(newdf.groupby([newdf["Date"].dt.date]).count()["Case Number"])
newdf = newdf.reset_index()
newdf.index = newdf.Date
newdf['Date'] = pd.to_datetime(newdf['Date'], errors='coerce')
newdf = newdf.asfreq('D')
newdf = newdf.groupby(pd.Grouper(freq="M")).sum()
newdf
# Out:
#             Case Number
# Date
# 2017-01-31       2206.0
# 2017-02-28       2377.0
# 2017-03-31       3326.0
# 2017-04-30       2186.0
# 2017-05-31       2581.0
# ...                 ...
# 2022-04-30       1871.0
# 2022-05-31       1787.0
# 2022-06-30       2112.0
# 2022-07-31       1959.0
# 2022-08-31       1351.0
#
# [68 rows x 1 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 68 entries, 2017-01-31 to 2022-08-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Case Number  68 non-null     float64
# dtypes: float64(1)
# memory usage: 1.1 KB

# %%
f = Forecaster(y=newdf['Case Number'],current_dates=newdf.index)
f
# Out:
# Forecaster(
#     DateStartActuals=2017-01-31T00:00:00.000000000
#     DateEndActuals=2022-08-31T00:00:00.000000000
#     Freq=M
#     N_actuals=68
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
#     GridsFile=Grids
# )

# %%
f.plot_pacf(lags=26)
plt.show()

# %%
f.seasonal_decompose().plot()
plt.show()

# %%
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
stat
# Out:
# 0.8334862782736289

# %%
pval
# Out:
# 0.992157914806683

# %%
f.set_test_length(24)       
f.generate_future_dates(12)
f.set_estimator('lstm')

# %%
f.manual_forecast(call_me='lstm_default')
f.plot_test_set(ci=True)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.2955
# 1/1 [==============================] - 0s 246ms/step
# 2/2 [==============================] - 1s 0s/step - loss: 0.2887
# 1/1 [==============================] - 0s 212ms/step
# 2/2 [==============================] - 0s 2ms/step
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.manual_forecast(call_me='lstm_24lags',lags=12)
f.plot_test_set(ci=True)
# Out:
# 1/1 [==============================] - 1s 968ms/step - loss: 0.3140
# 1/1 [==============================] - 0s 271ms/step
# 2/2 [==============================] - 1s 21ms/step - loss: 0.2944
# 1/1 [==============================] - 0s 212ms/step
# 2/2 [==============================] - 0s 2ms/step
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.manual_forecast(call_me='lstm_24lags_5epochs',
                  lags=12,
                  epochs=10,
                  validation_split=.2,
                  shuffle=True)
f.plot_test_set(ci=False)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.3308 - val_loss: 0.3245
# Epoch 2/10
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3289 - val_loss: 0.3226
# Epoch 3/10
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3270 - val_loss: 0.3207
# Epoch 4/10
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3251 - val_loss: 0.3188
# Epoch 5/10
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3232 - val_loss: 0.3170
# Epoch 6/10
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3214 - val_loss: 0.3152
# Epoch 7/10
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3195 - val_loss: 0.3133
# Epoch 8/10
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3176 - val_loss: 0.3115
# Epoch 9/10
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3158 - val_loss: 0.3097
# Epoch 10/10
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3139 - val_loss: 0.3080
# 1/1 [==============================] - 0s 214ms/step
# Epoch 1/10
# 2/2 [==============================] - 1s 270ms/step - loss: 0.3404 - val_loss: 0.3274
# Epoch 2/10
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3341 - val_loss: 0.3219
# Epoch 3/10
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3280 - val_loss: 0.3165
# Epoch 4/10
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3221 - val_loss: 0.3113
# Epoch 5/10
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3164 - val_loss: 0.3063
# Epoch 6/10
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3109 - val_loss: 0.3014
# Epoch 7/10
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3056 - val_loss: 0.2967
# Epoch 8/10
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3005 - val_loss: 0.2920
# Epoch 9/10
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2955 - val_loss: 0.2875
# Epoch 10/10
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2907 - val_loss: 0.2830
# 1/1 [==============================] - 0s 222ms/step
# 2/2 [==============================] - 0s 3ms/step
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
from tensorflow.keras.callbacks import EarlyStopping
f.manual_forecast(call_me='lstm_24lags_earlystop_3layers',
                  lags=12,
                  epochs=25,
                  validation_split=.2,
                  shuffle=True,
                  callbacks=EarlyStopping(monitor='val_loss',
                                          patience=5),
                  lstm_layer_sizes=(16,16,16),
                  dropout=(0,0,0))
f.plot_test_set(ci=True)
# Out:
# Epoch 1/25
# 1/1 [==============================] - 3s 3s/step - loss: 0.3231 - val_loss: 0.3087
# Epoch 2/25
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3204 - val_loss: 0.3058
# Epoch 3/25
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3178 - val_loss: 0.3029
# Epoch 4/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3153 - val_loss: 0.3001
# Epoch 5/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3127 - val_loss: 0.2973
# Epoch 6/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3101 - val_loss: 0.2943
# Epoch 7/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3074 - val_loss: 0.2912
# Epoch 8/25
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3047 - val_loss: 0.2880
# Epoch 9/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3019 - val_loss: 0.2845
# Epoch 10/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2989 - val_loss: 0.2808
# Epoch 11/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2957 - val_loss: 0.2768
# Epoch 12/25
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2924 - val_loss: 0.2725
# Epoch 13/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2888 - val_loss: 0.2681
# Epoch 14/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2849 - val_loss: 0.2632
# Epoch 15/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2807 - val_loss: 0.2584
# Epoch 16/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2760 - val_loss: 0.2532
# Epoch 17/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2714 - val_loss: 0.2480
# Epoch 18/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2666 - val_loss: 0.2424
# Epoch 19/25
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2615 - val_loss: 0.2372
# Epoch 20/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2560 - val_loss: 0.2321
# Epoch 21/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2506 - val_loss: 0.2274
# Epoch 22/25
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2453 - val_loss: 0.2227
# Epoch 23/25
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2401 - val_loss: 0.2188
# Epoch 24/25
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2356 - val_loss: 0.2167
# Epoch 25/25
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2310 - val_loss: 0.2161
# 1/1 [==============================] - 1s 697ms/step
# Epoch 1/25
# 2/2 [==============================] - 3s 672ms/step - loss: 0.2866 - val_loss: 0.2831
# Epoch 2/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2792 - val_loss: 0.2764
# Epoch 3/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2716 - val_loss: 0.2691
# Epoch 4/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2636 - val_loss: 0.2610
# Epoch 5/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2551 - val_loss: 0.2520
# Epoch 6/25
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2461 - val_loss: 0.2424
# Epoch 7/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2370 - val_loss: 0.2321
# Epoch 8/25
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2279 - val_loss: 0.2219
# Epoch 9/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2189 - val_loss: 0.2123
# Epoch 10/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2108 - val_loss: 0.2026
# Epoch 11/25
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2034 - val_loss: 0.1932
# Epoch 12/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1980 - val_loss: 0.1854
# Epoch 13/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1934 - val_loss: 0.1803
# Epoch 14/25
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1896 - val_loss: 0.1764
# Epoch 15/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1868 - val_loss: 0.1722
# Epoch 16/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1831 - val_loss: 0.1683
# Epoch 17/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1791 - val_loss: 0.1644
# Epoch 18/25
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1752 - val_loss: 0.1612
# Epoch 19/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1715 - val_loss: 0.1587
# Epoch 20/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1683 - val_loss: 0.1569
# Epoch 21/25
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1661 - val_loss: 0.1550
# Epoch 22/25
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1642 - val_loss: 0.1531
# Epoch 23/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1633 - val_loss: 0.1518
# Epoch 24/25
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1624 - val_loss: 0.1508
# Epoch 25/25
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1616 - val_loss: 0.1499
# 1/1 [==============================] - 1s 652ms/step
# 2/2 [==============================] - 0s 3ms/step
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.manual_forecast(call_me='lstm_best',
                  lags=12,
                  batch_size=32,
                  epochs=15,
                  validation_split=.2,
                  shuffle=True,
                  activation='tanh',
                  optimizer='Adam',
                  learning_rate=0.001,
                  lstm_layer_sizes=(72,)*4,
                  dropout=(0,)*4,
                  plot_loss=True)
f.plot_test_set(order_by='LevelTestSetMAPE',models='top_2',ci=True)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 5s 5s/step - loss: 0.3223 - val_loss: 0.3044
# Epoch 2/15
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3150 - val_loss: 0.2963
# Epoch 3/15
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3066 - val_loss: 0.2861
# Epoch 4/15
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2962 - val_loss: 0.2731
# Epoch 5/15
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2825 - val_loss: 0.2559
# Epoch 6/15
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2641 - val_loss: 0.2340
# Epoch 7/15
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2406 - val_loss: 0.2135
# Epoch 8/15
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2157 - val_loss: 0.2077
# Epoch 9/15
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2035 - val_loss: 0.2145
# Epoch 10/15
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2026 - val_loss: 0.2303
# Epoch 11/15
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2034 - val_loss: 0.2386
# Epoch 12/15
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1967 - val_loss: 0.2357
# Epoch 13/15
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1847 - val_loss: 0.2281
# Epoch 14/15
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1747 - val_loss: 0.2218
# Epoch 15/15
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1736 - val_loss: 0.2179
# 1/1 [==============================] - 1s 812ms/step
# Epoch 1/15
# 2/2 [==============================] - 5s 913ms/step - loss: 0.2897 - val_loss: 0.2785
# Epoch 2/15
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2752 - val_loss: 0.2604
# Epoch 3/15
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2541 - val_loss: 0.2289
# Epoch 4/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2213 - val_loss: 0.1811
# Epoch 5/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1865 - val_loss: 0.1660
# Epoch 6/15
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1800 - val_loss: 0.1701
# Epoch 7/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1791 - val_loss: 0.1546
# Epoch 8/15
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1656 - val_loss: 0.1554
# Epoch 9/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1638 - val_loss: 0.1607
# Epoch 10/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1674 - val_loss: 0.1585
# Epoch 11/15
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1667 - val_loss: 0.1515
# Epoch 12/15
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1628 - val_loss: 0.1488
# Epoch 13/15
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1626 - val_loss: 0.1502
# Epoch 14/15
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1630 - val_loss: 0.1522
# Epoch 15/15
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1629 - val_loss: 0.1540
# 1/1 [==============================] - 1s 854ms/step
# 2/2 [==============================] - 0s 5ms/step
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %% [markdown]
# # MLR Forecasting

# %%
f.set_estimator('mlr') # 1. choose the mlr estimator
f.add_ar_terms(12) # 2. add regressors (12 lagged terms)
f.add_seasonal_regressors('month','quarter',dummy=True) # 2.
f.add_seasonal_regressors('year') # 2.
# f.add_time_trend() # 2.
# f.diff() # 3. difference non-stationary data

# %%
f.manual_forecast()
f.plot_test_set(order_by='LevelTestSetMAPE',models='top_2')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.plot_test_set(models='mlr',ci=True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.plot(models=['mlr','lstm_best'],
       order_by='LevelTestSetMAPE',
       level=True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Values'>

# %%
f.export('model_summaries',determine_best_by='LevelTestSetMAPE')[
    ['ModelNickname',
     'LevelTestSetMAPE',
     'LevelTestSetRMSE',
     'LevelTestSetR2',
     'best_model']
]
# Out:
#                    ModelNickname  LevelTestSetMAPE  LevelTestSetRMSE  \
# 0                    lstm_24lags          0.321103       1426.685265
# 1                   lstm_default          0.344099       1343.889730
# 2            lstm_24lags_5epochs          0.352683       1337.608530
# 3  lstm_24lags_earlystop_3layers          0.373971       1144.884409
# 4                      lstm_best          0.417081       1071.400173
# 5                            mlr          0.686118       1777.303096
#
#    LevelTestSetR2  best_model
# 0       -1.352406        True
# 1       -1.087292       False
# 2       -1.067826       False
# 3       -0.514883       False
# 4       -0.326659       False
# 5       -2.650723       False

# %%
f.generate_future_dates(12)
f.set_test_length(.2)
f.set_estimator('arima')
f.manual_forecast(call_me='arima1')

# %% [markdown]
# # Auto-ARIMA Approach

# %%
auto_arima(
    f,
    start_P=1,
    start_q=1,
    max_p=6,
    max_q=6,
    m=12,
    seasonal=True,
    max_P=4, 
    max_D=4,
    max_Q=4,
    max_d=4,
    trace=True,
    error_action='ignore',
    suppress_warnings=True,
    stepwise=True,
    information_criterion="aic",
    alpha=0.05,
    scoring='mse',
    call_me='arima3',
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=629.146, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=579.873, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=627.241, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=616.511, Time=0.07 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=596.404, Time=0.19 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=588.964, Time=0.06 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=580.900, Time=0.14 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=577.896, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=614.706, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[12]             : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=inf, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=594.404, Time=0.11 sec
#  ARIMA(1,1,0)(2,0,1)[12]             : AIC=572.650, Time=0.51 sec
#  ARIMA(1,1,0)(3,0,1)[12]             : AIC=inf, Time=0.95 sec
#  ARIMA(1,1,0)(2,0,2)[12]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,1,0)(1,0,2)[12]             : AIC=inf, Time=0.42 sec
#  ARIMA(1,1,0)(3,0,0)[12]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,1,0)(3,0,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(0,1,0)(2,0,1)[12]             : AIC=582.695, Time=0.11 sec
#  ARIMA(2,1,0)(2,0,1)[12]             : AIC=569.169, Time=0.61 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(2,1,0)(2,0,0)[12]             : AIC=inf, Time=0.19 sec
#  ARIMA(2,1,0)(3,0,1)[12]             : AIC=inf, Time=0.95 sec
#  ARIMA(2,1,0)(2,0,2)[12]             : AIC=inf, Time=0.58 sec
#  ARIMA(2,1,0)(1,0,0)[12]             : AIC=578.920, Time=0.09 sec
#  ARIMA(2,1,0)(1,0,2)[12]             : AIC=569.647, Time=0.57 sec
#  ARIMA(2,1,0)(3,0,0)[12]             : AIC=inf, Time=0.38 sec
#  ARIMA(2,1,0)(3,0,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(3,1,0)(2,0,1)[12]             : AIC=572.510, Time=0.81 sec
#  ARIMA(2,1,1)(2,0,1)[12]             : AIC=566.847, Time=0.53 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=inf, Time=0.34 sec
#  ARIMA(2,1,1)(2,0,0)[12]             : AIC=inf, Time=nan sec
#  ARIMA(2,1,1)(3,0,1)[12]             : AIC=568.680, Time=1.40 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=574.206, Time=0.15 sec
#  ARIMA(2,1,1)(1,0,2)[12]             : AIC=inf, Time=nan sec
#  ARIMA(2,1,1)(3,0,0)[12]             : AIC=567.539, Time=1.16 sec
#  ARIMA(2,1,1)(3,0,2)[12]             : AIC=inf, Time=1.85 sec
#  ARIMA(1,1,1)(2,0,1)[12]             : AIC=inf, Time=0.42 sec
#  ARIMA(3,1,1)(2,0,1)[12]             : AIC=inf, Time=0.76 sec
#  ARIMA(2,1,2)(2,0,1)[12]             : AIC=inf, Time=0.63 sec
#  ARIMA(1,1,2)(2,0,1)[12]             : AIC=570.670, Time=0.63 sec
#  ARIMA(3,1,2)(2,0,1)[12]             : AIC=inf, Time=0.85 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.68 sec
#
# Best model:  ARIMA(2,1,1)(2,0,1)[12]
# Total fit time: 23.438 seconds

# %%
f.plot_test_set(ci=False,models='arima3')
plt.title('ARIMA Test-Set Performance',size=14)
plt.show()

# %%
f.plot(ci=False,models='arima3')
plt.title('ARIMA Forecast Performance',size=14)
plt.show()

# %%
pd.options.display.max_colwidth = 100
results = f.export(to_excel=True,
                   excel_name='arima_results.xlsx',
                   determine_best_by='TestSetMAPE')

# %%
results["test_set_predictions"]
# Out:
#          DATE  actual      arima3      arima1
# 55 2021-08-31    65.0   55.750675  153.418179
# 56 2021-09-30    89.0   60.856285  153.418179
# 57 2021-10-31    90.0  129.185294  153.418179
# 58 2021-11-30   102.0   93.212717  153.418179
# 59 2021-12-31   139.0  112.884538  153.418179
# 60 2022-01-31   230.0  276.489085  153.418179
# 61 2022-02-28   134.0  110.514659  153.418179
# 62 2022-03-31   151.0  151.518475  153.418179
# 63 2022-04-30   105.0  102.004790  153.418179
# 64 2022-05-31    96.0   48.783197  153.418179
# 65 2022-06-30   134.0   58.542969  153.418179
# 66 2022-07-31    98.0   70.666242  153.418179
# 67 2022-08-31    47.0   40.320578  153.418179

# %%
results["all_fcsts"]
# Out:
#          DATE      arima1      arima3
# 0  2022-09-30  145.852937   85.838542
# 1  2022-10-31  145.852937   93.508110
# 2  2022-11-30  145.852937   88.895985
# 3  2022-12-31  145.852937  104.207094
# 4  2023-01-31  145.852937  140.332897
# 5  2023-02-28  145.852937  106.256850
# 6  2023-03-31  145.852937  118.861035
# 7  2023-04-30  145.852937   97.988433
# 8  2023-05-31  145.852937   79.690987
# 9  2023-06-30  145.852937  112.597160
# 10 2023-07-31  145.852937  102.097625
# 11 2023-08-31  145.852937   53.523522

# %% [markdown]
# # =============================================================

# %%
f.set_validation_length(12)
grid = {
    'order':[(1,1,1),(1,1,0),(0,1,1)],
    'seasonal_order':[(2,1,1,12),(1,1,1,12),(2,1,0,12),(0,1,0,12)]
}

f.ingest_grid(grid)
f.tune()
f.auto_forecast(call_me='arima4')

f.plot_test_set(ci=False,models='arima4')
plt.title('ARIMA Test-Set Performance',size=14)
plt.show()

f.plot(ci=False,models='arima4')
plt.title('ARIMA Forecast Performance',size=14)
plt.show()

f.regr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   68
# Model:             ARIMA(1, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -408.452
# Date:                            Fri, 26 Aug 2022   AIC                            824.904
# Time:                                    16:51:44   BIC                            832.933
# Sample:                                         0   HQIC                           828.009
#                                              - 68
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2737      0.188     -1.454      0.146      -0.643       0.095
# ar.S.L12       0.3900      0.330      1.182      0.237      -0.257       1.037
# ma.S.L12      -0.9902     10.486     -0.094      0.925     -21.541      19.561
# sigma2      1.333e+05   1.36e+06      0.098      0.922   -2.53e+06     2.8e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.61   Jarque-Bera (JB):                12.44
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                             0.46
# Prob(H) (two-sided):                  0.54   Kurtosis:                         5.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pd.options.display.max_colwidth = 100
results = f.export(to_excel=True,
                   excel_name='arima_results.xlsx',
                   determine_best_by='TestSetMAPE')

# %%
results["test_set_predictions"]
results["all_fcsts"]
# Out:
#          DATE  actual       arima4       arima2       arima3       arima1
# 55 2021-08-31  1517.0  1702.625656  1864.583179  1889.436807  1711.981871
# 56 2021-09-30  2300.0  2582.738084  2511.477406  3386.024467  1711.981871
# 57 2021-10-31  2915.0  3682.114872  3633.539862  4377.117595  1711.981871
# 58 2021-11-30  1417.0  1161.872889  1299.856642  1718.021872  1711.981871
# 59 2021-12-31   710.0   487.171588   655.024484   895.707528  1711.981871
# 60 2022-01-31   968.0   879.611172   972.754895  1298.928629  1711.981871
# 61 2022-02-28   979.0   756.989674   883.125150  1094.670314  1711.981871
# 62 2022-03-31  1157.0  1125.841442  1230.653855  1424.927616  1711.981871
# 63 2022-04-30   914.0   874.646439   942.788336  1298.279566  1711.981871
# 64 2022-05-31   777.0   725.686055   904.774353   995.411103  1711.981871
# 65 2022-06-30   952.0   946.706136  1092.267719  1250.822872  1711.981871
# 66 2022-07-31   870.0  1022.557076  1239.876905  1301.247947  1711.981871
# 67 2022-08-31   581.0  1628.150926  1971.076297  1895.557101  1711.981871

# %%
results["all_fcsts"]
# Out:
#          DATE       arima1       arima2       arima3       arima4
# 0  2022-09-30  1620.819437  1932.067910  1889.421139  1625.693075
# 1  2022-10-31  1620.819437  2981.945128  2733.757837  2382.789529
# 2  2022-11-30  1620.819437   791.024890  1294.865269   430.849719
# 3  2022-12-31  1620.819437   236.550741   619.085756  -235.628436
# 4  2023-01-31  1620.819437   619.801875   909.955076    90.661312
# 5  2023-02-28  1620.819437   525.169692   940.730385    48.910194
# 6  2023-03-31  1620.819437   854.534913  1144.475346   338.270787
# 7  2023-04-30  1620.819437   549.847584   931.090655    62.277341
# 8  2023-05-31  1620.819437   428.037525   790.075445   -64.500533
# 9  2023-06-30  1620.819437   631.389797   975.325472   133.178434
# 10 2023-07-31  1620.819437   717.384464   891.573538   122.255385
# 11 2023-08-31  1620.819437   883.178079   703.875850   250.006508

# %%
def isUniqueChars(st):
 
    # String length cannot be more than
    # 256.
    if len(st) > 256:
        return False
 
    # Initialize occurrences of all characters
    char_set = [False] * 128
 
    # For every character, check if it exists
    # in char_set
    for i in range(0, len(st)):
 
        # Find ASCII value and check if it
        # exists in set.
        val = ord(st[i])
        if char_set[val]:
            return False
 
        char_set[val] = True
 
    return True
 
l1 = ["abcd","123ac","abca"]
result = []
for i in l1:
    if isUniqueChars(i) == True:
        result.append(i)
print(result)
# Out:
# True

# %%
# Out:
# ['abcd', '123ac']

# %%
def isUniqueChars(st):
 
    char_set = [False] * 128
 
    for i in range(0, len(st)):

        val = ord(st[i])
        if char_set[val]:
            return False
 
        char_set[val] = True
 
    return True
 
l1 = ["abcd","123ac","abca"]
result = []
for i in l1:
    if isUniqueChars(i) == True:
        result.append(i)
print(result)
# Out:
# ['abcd', '123ac']

# %%
char_set = [False] * 128
char_set
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
ord('a')
# Out:
# 97

# %%
ss = " he l"

count = 0
for i in ss.replace(" ", ""):
    count = count +1 
    
print(count)
# Out:
# 3

# %%
len(ss.replace(" ", ""))
# Out:
# 3

# %%
def isUniqueChars(st):
 
    char_set = [False] * 128
 
    for i in range(0, len(st)):

        val = ord(st[i])
        if char_set[val]:
            return False
 
        char_set[val] = True
 
    return True
 
l1 = ["abcd","123ac","abca"]
result = []
for i in l1:
    if isUniqueChars(i) == True:
        result.append(i)
print(result)
